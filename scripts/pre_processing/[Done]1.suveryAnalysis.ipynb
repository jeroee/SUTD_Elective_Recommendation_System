# %%
import pandas as pd
from os import path
## inorder to obtain the relative file path
## https://stackoverflow.com/questions/7165749/open-file-in-a-relative-location-in-python 
## ../ refer to looking into the folder above
relativePath = path.relpath("../../data/survey_processing/CustomerFeedback(Responses).xlsx")
## require the engine = 'openpyxl' to read the xlsx
suvery = pd.read_excel(relativePath, index_col = 0,engine="openpyxl")
suvery.head()
# Out:
#                         Pillar ESD Focus Track [Aviation]  \
# Timestamp
# 2021-06-06 20:49:18.800   ISTD                        NaN
# 2021-06-06 21:01:33.686    ESD                        NaN
# NaT                       None                       None
# NaT                       None                       None
# 2021-06-07 09:37:27.103   ISTD                        NaN
#
#                         ESD Focus Track [Business Analytics and Operations Research]  \
# Timestamp
# 2021-06-06 20:49:18.800                                                NaN
# 2021-06-06 21:01:33.686                                     Check if taken
# NaT                                                                   None
# NaT                                                                   None
# 2021-06-07 09:37:27.103                                                NaN
#
#                         ESD Focus Track [Financial Services]  \
# Timestamp
# 2021-06-06 20:49:18.800                                  NaN
# 2021-06-06 21:01:33.686                                  NaN
# NaT                                                     None
# NaT                                                     None
# 2021-06-07 09:37:27.103                                  NaN
#
#                         ESD Focus Track [Supply Chain & Logistics]  \
# Timestamp
# 2021-06-06 20:49:18.800                                        NaN
# 2021-06-06 21:01:33.686                                        NaN
# NaT                                                           None
# NaT                                                           None
# 2021-06-07 09:37:27.103                                        NaN
#
#                         ESD Focus Track [Urban Infrastructure Systems]  \
# Timestamp
# 2021-06-06 20:49:18.800                                            NaN
# 2021-06-06 21:01:33.686                                            NaN
# NaT                                                               None
# NaT                                                               None
# 2021-06-07 09:37:27.103                                            NaN
#
#                         ESD Focus Track [No focus track / Customized focus track]  \
# Timestamp
# 2021-06-06 20:49:18.800                                                NaN
# 2021-06-06 21:01:33.686                                                NaN
# NaT                                                                   None
# NaT                                                                   None
# 2021-06-07 09:37:27.103                                                NaN
#
#                          ESD Focus Track [Others] ISTD Focus Track [AI]  \
# Timestamp
# 2021-06-06 20:49:18.800                       NaN        Check if taken
# 2021-06-06 21:01:33.686                       NaN                   NaN
# NaT                                           NaN                  None
# NaT                                           NaN                  None
# 2021-06-07 09:37:27.103                       NaN                   NaN
#
#                         ISTD Focus Track [Data Analytics]  ...  \
# Timestamp                                                  ...
# 2021-06-06 20:49:18.800                    Check if taken  ...
# 2021-06-06 21:01:33.686                               NaN  ...
# NaT                                                  None  ...
# NaT                                                  None  ...
# 2021-06-07 09:37:27.103                    Check if taken  ...
#
#                         01.107 Urban Transportation (TAE )  \
# Timestamp
# 2021-06-06 20:49:18.800                                NaN
# 2021-06-06 21:01:33.686                                NaN
# NaT                                                   None
# NaT                                                   None
# 2021-06-07 09:37:27.103                                NaN
#
#                          Other ESD Modules if not listed  \
# Timestamp
# 2021-06-06 20:49:18.800                              NaN
# 2021-06-06 21:01:33.686                              NaN
# NaT                                                 None
# NaT                                                 None
# 2021-06-07 09:37:27.103                              NaN
#
#                         Other ESD Modules if not listed.1  \
# Timestamp
# 2021-06-06 20:49:18.800                               NaN
# 2021-06-06 21:01:33.686                               NaN
# NaT                                                  None
# NaT                                                  None
# 2021-06-07 09:37:27.103                               NaN
#
#                          Other ISTD Modules if not listed Unnamed: 102  \
# Timestamp
# 2021-06-06 20:49:18.800                               NaN          NaN
# 2021-06-06 21:01:33.686              50.004 Intro to algo          NaN
# NaT                                                  None          NaN
# NaT                                                  None          NaN
# 2021-06-07 09:37:27.103                               NaN          NaN
#
#                               Other ISTD Modules if not listed.1  \
# Timestamp
# 2021-06-06 20:49:18.800                                      NaN
# 2021-06-06 21:01:33.686  50. 004 Intro to Algo - MathLab, python
# NaT                                                         None
# NaT                                                         None
# 2021-06-07 09:37:27.103                                      NaN
#
#                          What are your academic/career interest?  \
# Timestamp
# 2021-06-06 20:49:18.800                             Data Science
# 2021-06-06 21:01:33.686                             Data Science
# NaT                                                         None
# NaT                                                         None
# 2021-06-07 09:37:27.103                             Data Science
#
#                          What are your skills of interest? Unnamed: 106  \
# Timestamp
# 2021-06-06 20:49:18.800                     keras, pytorch          NaN
# 2021-06-06 21:01:33.686      python, R and dashboard tools          NaN
# NaT                                                   None          NaN
# NaT                                                   None          NaN
# 2021-06-07 09:37:27.103                 data visualization          NaN
#
#                         Unnamed: 107
# Timestamp
# 2021-06-06 20:49:18.800          NaN
# 2021-06-06 21:01:33.686          NaN
# NaT                              NaN
# NaT                              NaN
# 2021-06-07 09:37:27.103          NaN
#
# [5 rows x 107 columns]

# %%
## data cleaning
## drop from column
suvery.dropna(axis= 1, how = 'all', inplace= True)
## drop from row
suvery.dropna(axis= 0, how = 'all', inplace= True)
## replace column value to 1 if 'Check if taken' or ' Check if taken or taking during Term 6 to 8'
suvery.replace('Check if taken', 1, inplace = True)
suvery.replace('Check if taken or taking during Term 6 to 8', 1, inplace = True)
suvery.describe(include ='all')
# Out:
#        Pillar  ESD Focus Track [Aviation]  \
# count      41                         1.0
# unique      2                         NaN
# top       ESD                         NaN
# freq       28                         NaN
# mean      NaN                         1.0
# std       NaN                         NaN
# min       NaN                         1.0
# 25%       NaN                         1.0
# 50%       NaN                         1.0
# 75%       NaN                         1.0
# max       NaN                         1.0
#
#         ESD Focus Track [Business Analytics and Operations Research]  \
# count                                                21.0
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                                  1.0
# std                                                   0.0
# min                                                   1.0
# 25%                                                   1.0
# 50%                                                   1.0
# 75%                                                   1.0
# max                                                   1.0
#
#         ESD Focus Track [Financial Services]  \
# count                                    5.0
# unique                                   NaN
# top                                      NaN
# freq                                     NaN
# mean                                     1.0
# std                                      0.0
# min                                      1.0
# 25%                                      1.0
# 50%                                      1.0
# 75%                                      1.0
# max                                      1.0
#
#         ESD Focus Track [Supply Chain & Logistics]  \
# count                                          2.0
# unique                                         NaN
# top                                            NaN
# freq                                           NaN
# mean                                           1.0
# std                                            0.0
# min                                            1.0
# 25%                                            1.0
# 50%                                            1.0
# 75%                                            1.0
# max                                            1.0
#
#         ESD Focus Track [Urban Infrastructure Systems]  \
# count                                              3.0
# unique                                             NaN
# top                                                NaN
# freq                                               NaN
# mean                                               1.0
# std                                                0.0
# min                                                1.0
# 25%                                                1.0
# 50%                                                1.0
# 75%                                                1.0
# max                                                1.0
#
#         ESD Focus Track [No focus track / Customized focus track]  \
# count                                                 2.0
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                                  1.0
# std                                                   0.0
# min                                                   1.0
# 25%                                                   1.0
# 50%                                                   1.0
# 75%                                                   1.0
# max                                                   1.0
#
#         ISTD Focus Track [AI]  ISTD Focus Track [Data Analytics]  \
# count                     7.0                               10.0
# unique                    NaN                                NaN
# top                       NaN                                NaN
# freq                      NaN                                NaN
# mean                      1.0                                1.0
# std                       0.0                                0.0
# min                       1.0                                1.0
# 25%                       1.0                                1.0
# 50%                       1.0                                1.0
# 75%                       1.0                                1.0
# max                       1.0                                1.0
#
#         ISTD Focus Track [Financial Technology]  ...  \
# count                                       2.0  ...
# unique                                      NaN  ...
# top                                         NaN  ...
# freq                                        NaN  ...
# mean                                        1.0  ...
# std                                         0.0  ...
# min                                         1.0  ...
# 25%                                         1.0  ...
# 50%                                         1.0  ...
# 75%                                         1.0  ...
# max                                         1.0  ...
#
#                01.116 AI for Healthcare (Term 7) (TAE)  \
# count                                                1
# unique                                               1
# top     OpenCV, Computer Vision, Deep Learning, Python
# freq                                                 1
# mean                                               NaN
# std                                                NaN
# min                                                NaN
# 25%                                                NaN
# 50%                                                NaN
# 75%                                                NaN
# max                                                NaN
#
#         01.102 Energy Systems and Management (TAE )  \
# count                                             4
# unique                                            4
# top     Optimisation Models in an Application Space
# freq                                              1
# mean                                            NaN
# std                                             NaN
# min                                             NaN
# 25%                                             NaN
# 50%                                             NaN
# 75%                                             NaN
# max                                             NaN
#
#        01.104 Networked Life (TAE )  01.107 Urban Transportation (TAE )  \
# count                            13                                   2
# unique                           11                                   2
# top                          Python    Aimsun Software and traffic sims
# freq                              3                                   1
# mean                            NaN                                 NaN
# std                             NaN                                 NaN
# min                             NaN                                 NaN
# 25%                             NaN                                 NaN
# 50%                             NaN                                 NaN
# 75%                             NaN                                 NaN
# max                             NaN                                 NaN
#
#             Other ESD Modules if not listed  \
# count                                     4
# unique                                    4
# top     Computational Data Science ISTD Mod
# freq                                      1
# mean                                    NaN
# std                                     NaN
# min                                     NaN
# 25%                                     NaN
# 50%                                     NaN
# 75%                                     NaN
# max                                     NaN
#
#                    Other ESD Modules if not listed.1  \
# count                                              1
# unique                                             1
# top     40.015 Simulation Modelling and Analysis, JS
# freq                                               1
# mean                                             NaN
# std                                              NaN
# min                                              NaN
# 25%                                              NaN
# 50%                                              NaN
# 75%                                              NaN
# max                                              NaN
#
#          Other ISTD Modules if not listed  \
# count                                   5
# unique                                  4
# top     50.004 Introduction to Algorithms
# freq                                    2
# mean                                  NaN
# std                                   NaN
# min                                   NaN
# 25%                                   NaN
# 50%                                   NaN
# 75%                                   NaN
# max                                   NaN
#
#                        Other ISTD Modules if not listed.1  \
# count                                                   3
# unique                                                  3
# top     50.004 Introduction to Algorithms - data struc...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#         What are your academic/career interest?  \
# count                                        41
# unique                                       32
# top                                Data Science
# freq                                          5
# mean                                        NaN
# std                                         NaN
# min                                         NaN
# 25%                                         NaN
# 50%                                         NaN
# 75%                                         NaN
# max                                         NaN
#
#         What are your skills of interest?
# count                                  41
# unique                                 30
# top                                Coding
# freq                                    4
# mean                                  NaN
# std                                   NaN
# min                                   NaN
# 25%                                   NaN
# 50%                                   NaN
# 75%                                   NaN
# max                                   NaN
#
# [11 rows x 86 columns]

# %%
suvery.describe(include ='all')['40.240 Investment Science']
# Out:
# count                       6
# unique                      6
# top       CAPM, stock pricing
# freq                        1
# mean                      NaN
# std                       NaN
# min                       NaN
# 25%                       NaN
# 50%                       NaN
# 75%                       NaN
# max                       NaN
# Name: 40.240 Investment Science, dtype: object

# %% [markdown]
# # Data Anlaysis of Suvery

# %%
## Analysis of What are your academic/career interest?
columnsOfInterest = suvery.columns[-2]
suvery[columnsOfInterest].value_counts(normalize = True)
# Out:
# Data Science                                                            0.121951
# Math                                                                    0.048780
# operation research                                                      0.048780
# Data analytics                                                          0.048780
# Data                                                                    0.048780
# Bussiness Metrics                                                       0.048780
# Deep learning                                                           0.024390
# Business Analytics, Data Scientists, Marketing, Software Engineering    0.024390
# Finance                                                                 0.024390
# computer science                                                        0.024390
# Supply Chain management                                                 0.024390
# Finance, Software Engineering                                           0.024390
# AI                                                                      0.024390
# machine learning                                                        0.024390
# Software Engineering                                                    0.024390
# Cybersec                                                                0.024390
# automation                                                              0.024390
# software engineering                                                    0.024390
# Technology                                                              0.024390
# data science, project management, finance                               0.024390
# Digital humanities, NLP                                                 0.024390
# backend dev                                                             0.024390
# Data Analytics                                                          0.024390
# analysis                                                                0.024390
# Transportation                                                          0.024390
# finance                                                                 0.024390
# Airport opertaions                                                      0.024390
# retirement shop owner                                                   0.024390
# Supply Chain                                                            0.024390
# Software Engineering, Data Science, Consultancy                         0.024390
# Finance, banking, data analytics                                        0.024390
# mathematics                                                             0.024390
# Name: What are your academic/career interest?, dtype: float64

# %%
## What are your skills of interest?
columnsOfInterest = suvery.columns[-1]
suvery[columnsOfInterest].value_counts(normalize = True)
# Out:
# Coding                                                              0.097561
# Programming                                                         0.073171
# programming                                                         0.048780
# Modeling                                                            0.048780
# modeling                                                            0.048780
# R                                                                   0.048780
# data visualization                                                  0.048780
# python                                                              0.048780
# coding, jira, bloomberg                                             0.024390
# simluation modeling                                                 0.024390
# project management, supply chain management                         0.024390
# Coding, sound and light design, electronics                         0.024390
# coding                                                              0.024390
# Web Dev, Machine Learning, Basketball, Reading, Music               0.024390
# Coding, Web Dev, Data Analytics                                     0.024390
# mechanic, woodworking                                               0.024390
# Coding, Illustrator, Editing                                        0.024390
# excel                                                               0.024390
# Keras, Pytorch                                                      0.024390
# Tool for optimization                                               0.024390
# Coding, Web Dev, Software Dev                                       0.024390
# Photoshop, coding                                                   0.024390
# App Dev                                                             0.024390
# valuation                                                           0.024390
# Photoshop, machine learning, optimisation, portfolio management     0.024390
# python, R and dashboard tools                                       0.024390
# Coding, drawing                                                     0.024390
# keras, pytorch                                                      0.024390
# web dev                                                             0.024390
# Data Analytics                                                      0.024390
# Name: What are your skills of interest?, dtype: float64

# %%
suvery.columns
'suvery columns'
# Out:
# 'suvery columns'

# %%
groupByPillar = suvery.groupby(by = ['Pillar']).count()

# %%
import matplotlib.pyplot as plt
FocusTrack = []
for columnName in suvery.columns:
    if 'Focus Track' in columnName:
        FocusTrack.append(columnName)

groupByPillar = suvery.groupby(by = ['Pillar']).count()
groupByPillar.plot.bar(y = FocusTrack,figsize = (8,4.5),rot=0, title = 'FocusTrack', grid = True)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5),
          fancybox=True, shadow=True, ncol=1)

# %%
ESDElective = []
for columnName in suvery.columns:
    if ('ESD Elective' in columnName) | ('ESD TAE Modules' in columnName):
        ESDElective.append(columnName)

groupByPillar = suvery.groupby(by = ['Pillar']).count()
groupByPillar.plot.bar(y = ESDElective,figsize = (16,9),rot=0, grid = True, title = 'Num Students based on sorted by pillar taking ESD Electives')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5),
          fancybox=True, shadow=True, ncol=1)

# %%
ISTDElective = []
for columnName in suvery.columns:
    if ('ISTD Elective' in columnName) | ('ISTD TAE Modules' in columnName):
        ISTDElective.append(columnName)
groupByPillar.plot.bar(y = ISTDElective,figsize = (16,9),rot=0, grid = True, title = 'Num Students based on sorted by pillar taking ISTD Electives')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5),
          fancybox=True, shadow=True, ncol=1)

# %%
groupByPillar
# Out:
#         ESD Focus Track [Aviation]  \
# Pillar
# ESD                              1
# ISTD                             0
#
#         ESD Focus Track [Business Analytics and Operations Research]  \
# Pillar
# ESD                                                    21
# ISTD                                                    0
#
#         ESD Focus Track [Financial Services]  \
# Pillar
# ESD                                        5
# ISTD                                       0
#
#         ESD Focus Track [Supply Chain & Logistics]  \
# Pillar
# ESD                                              2
# ISTD                                             0
#
#         ESD Focus Track [Urban Infrastructure Systems]  \
# Pillar
# ESD                                                  3
# ISTD                                                 0
#
#         ESD Focus Track [No focus track / Customized focus track]  \
# Pillar
# ESD                                                     2
# ISTD                                                    0
#
#         ISTD Focus Track [AI]  ISTD Focus Track [Data Analytics]  \
# Pillar
# ESD                         1                                  2
# ISTD                        6                                  8
#
#         ISTD Focus Track [Financial Technology]  ISTD Focus Track [Security]  \
# Pillar
# ESD                                           0                            0
# ISTD                                          2                            1
#
#         ...  01.116 AI for Healthcare (Term 7) (TAE)  \
# Pillar  ...
# ESD     ...                                        1
# ISTD    ...                                        0
#
#         01.102 Energy Systems and Management (TAE )  \
# Pillar
# ESD                                               4
# ISTD                                              0
#
#         01.104 Networked Life (TAE )  01.107 Urban Transportation (TAE )  \
# Pillar
# ESD                               13                                   2
# ISTD                               0                                   0
#
#         Other ESD Modules if not listed  Other ESD Modules if not listed.1  \
# Pillar
# ESD                                   4                                  1
# ISTD                                  0                                  0
#
#         Other ISTD Modules if not listed  Other ISTD Modules if not listed.1  \
# Pillar
# ESD                                    5                                   3
# ISTD                                   0                                   0
#
#         What are your academic/career interest?  \
# Pillar
# ESD                                          28
# ISTD                                         13
#
#         What are your skills of interest?
# Pillar
# ESD                                    28
# ISTD                                   13
#
# [2 rows x 85 columns]

# %% [markdown]
# # Queries Sampling
# This Section is to obtain the different types of queries based on the suvery

# %%
def textCleaning(_string):
    ## spacy tutorial https://www.analyticsvidhya.com/blog/2020/03/spacy-tutorial-learn-natural-language-processing/
    import spacy
    import re
    nlp = spacy.load('en_core_web_sm') 
    #create nlp object
    _string = re.sub('[,!@#$]', '', _string)
    doc = nlp(_string)
    doc = [token for token in doc if not token.is_stop]
    return(doc)

# %%
def extractFocusTrackInElectives(_singleElectiveDf,_singleElectivesLs):
    ## modules this track students took
        singleElectiveDf = _singleElectiveDf.dropna(axis= 1, how = 'all').copy()
    ## this have not factor what the electives mentioned in the Other electives
        trackLs = []
        for focusTrack in singleElectiveDf.columns:
            if ('Focus Track' in focusTrack): 
                trackLs.append(focusTrack)
        _singleElectivesLs.append(trackLs)

# %%
def extractingOpenEndedInput(_df,_ls,columnName):
    ## check the different inputs from What are your academic/career interest?
        interestOrSkills = list(set(_df[columnName]))
        interestOrSkills = [x.lower() for x in interestOrSkills] 
    ## tokenization and textCleaning to add value of the elective
        tokenization =[]
        for text in interestOrSkills:
            tokenized = textCleaning(text)
            tokenization.extend(tokenized)        
        tokenization = list(set(tokenization))
        _ls.append(tokenization)

# %%
def extractingRelevantElectiveIntertestSkills(_df):
    ## can add the count of the terms that appearing for each combination

    import pandas as pd
    ## check what focus track relates to the inputs in What are your academic/career interest?
    electivesLs = []
    for elective in _df.columns:
        if ('Elective' in elective) | ('TAE Modules' in elective):
            electivesLs.append(elective)

    ## dict to save all the focus track elective, interest and skills
    allElectivesDict = {}
    ## check What are your academic/career interest? input selected the focus track
    ## iterating from different columns to check what modules relate to them
    for electives in electivesLs:
    ## dict to store the electives, interest and skills for one track
        singleElectivesLs = []
    ## students taking this track students
    ## if electives == 1 
        electivesDf = _df[_df[electives] == 1]
        extractFocusTrackInElectives(electivesDf,singleElectivesLs)
    ## check the different inputs from 'What are your academic/career interest?'
        extractingOpenEndedInput(electivesDf,singleElectivesLs,'What are your academic/career interest?')
    ## check the different inputs from 'What are your skills of interest?'
        extractingOpenEndedInput(electivesDf,singleElectivesLs,'What are your skills of interest?')
    ## appending to allElectivesDict
        allElectivesDict[electives] = singleElectivesLs

    ## convert dict to df
    allElectivesDf = pd.DataFrame.from_dict(allElectivesDict, orient = 'index', columns =['FocusTracks','interest','skills'])

    return(allElectivesDf)

# %%
# extractingRelevantElectiveIntertestSkillsDf = extractingRelevantElectiveIntertestSkills(suvery)
# extractingRelevantElectiveIntertestSkillsDf

# %%
# ## export csv
# relativeSaveCSVPath = path.relpath("../../data/suveryData/suveryDataSorted.xlsx")
# extractingRelevantElectiveIntertestSkillsDf.to_excel(relativeSaveCSVPath)
