# %% [markdown]
# ## The purpose of the script
# This script is to convert the text from the suvery into word from suvery to modules
# <br>
# This is to merge 50% of the suvery to training dataset

# %%
import pandas as pd
from os import path
## inorder to obtain the relative file path
## https://stackoverflow.com/questions/7165749/open-file-in-a-relative-location-in-python 
## ../ refer to looking into the folder above
relativePath = path.relpath("../../data/survey_processing/CustomerFeedback(Responses).xlsx")
## require the engine = 'openpyxl' to read the xlsx
df = pd.read_excel(relativePath, index_col = 0,engine="openpyxl")
df.head()
# Out:
#                         Pillar ESD Focus Track [Aviation]  \
# Timestamp
# 2021-06-06 20:49:18.800   ISTD                        NaN
# 2021-06-06 21:01:33.686    ESD                        NaN
# NaT                       None                       None
# NaT                       None                       None
# 2021-06-07 09:37:27.103   ISTD                        NaN
#
#                         ESD Focus Track [Business Analytics and Operations Research]  \
# Timestamp
# 2021-06-06 20:49:18.800                                                NaN
# 2021-06-06 21:01:33.686                                     Check if taken
# NaT                                                                   None
# NaT                                                                   None
# 2021-06-07 09:37:27.103                                                NaN
#
#                         ESD Focus Track [Financial Services]  \
# Timestamp
# 2021-06-06 20:49:18.800                                  NaN
# 2021-06-06 21:01:33.686                                  NaN
# NaT                                                     None
# NaT                                                     None
# 2021-06-07 09:37:27.103                                  NaN
#
#                         ESD Focus Track [Supply Chain & Logistics]  \
# Timestamp
# 2021-06-06 20:49:18.800                                        NaN
# 2021-06-06 21:01:33.686                                        NaN
# NaT                                                           None
# NaT                                                           None
# 2021-06-07 09:37:27.103                                        NaN
#
#                         ESD Focus Track [Urban Infrastructure Systems]  \
# Timestamp
# 2021-06-06 20:49:18.800                                            NaN
# 2021-06-06 21:01:33.686                                            NaN
# NaT                                                               None
# NaT                                                               None
# 2021-06-07 09:37:27.103                                            NaN
#
#                         ESD Focus Track [No focus track / Customized focus track]  \
# Timestamp
# 2021-06-06 20:49:18.800                                                NaN
# 2021-06-06 21:01:33.686                                                NaN
# NaT                                                                   None
# NaT                                                                   None
# 2021-06-07 09:37:27.103                                                NaN
#
#                          ESD Focus Track [Others] ISTD Focus Track [AI]  \
# Timestamp
# 2021-06-06 20:49:18.800                       NaN        Check if taken
# 2021-06-06 21:01:33.686                       NaN                   NaN
# NaT                                           NaN                  None
# NaT                                           NaN                  None
# 2021-06-07 09:37:27.103                       NaN                   NaN
#
#                         ISTD Focus Track [Data Analytics]  ...  \
# Timestamp                                                  ...
# 2021-06-06 20:49:18.800                    Check if taken  ...
# 2021-06-06 21:01:33.686                               NaN  ...
# NaT                                                  None  ...
# NaT                                                  None  ...
# 2021-06-07 09:37:27.103                    Check if taken  ...
#
#                         01.107 Urban Transportation (TAE )  \
# Timestamp
# 2021-06-06 20:49:18.800                                NaN
# 2021-06-06 21:01:33.686                                NaN
# NaT                                                   None
# NaT                                                   None
# 2021-06-07 09:37:27.103                                NaN
#
#                          Other ESD Modules if not listed  \
# Timestamp
# 2021-06-06 20:49:18.800                              NaN
# 2021-06-06 21:01:33.686                              NaN
# NaT                                                 None
# NaT                                                 None
# 2021-06-07 09:37:27.103                              NaN
#
#                         Other ESD Modules if not listed.1  \
# Timestamp
# 2021-06-06 20:49:18.800                               NaN
# 2021-06-06 21:01:33.686                               NaN
# NaT                                                  None
# NaT                                                  None
# 2021-06-07 09:37:27.103                               NaN
#
#                          Other ISTD Modules if not listed Unnamed: 102  \
# Timestamp
# 2021-06-06 20:49:18.800                               NaN          NaN
# 2021-06-06 21:01:33.686              50.004 Intro to algo          NaN
# NaT                                                  None          NaN
# NaT                                                  None          NaN
# 2021-06-07 09:37:27.103                               NaN          NaN
#
#                               Other ISTD Modules if not listed.1  \
# Timestamp
# 2021-06-06 20:49:18.800                                      NaN
# 2021-06-06 21:01:33.686  50. 004 Intro to Algo - MathLab, python
# NaT                                                         None
# NaT                                                         None
# 2021-06-07 09:37:27.103                                      NaN
#
#                          What are your academic/career interest?  \
# Timestamp
# 2021-06-06 20:49:18.800                             Data Science
# 2021-06-06 21:01:33.686                             Data Science
# NaT                                                         None
# NaT                                                         None
# 2021-06-07 09:37:27.103                             Data Science
#
#                          What are your skills of interest? Unnamed: 106  \
# Timestamp
# 2021-06-06 20:49:18.800                     keras, pytorch          NaN
# 2021-06-06 21:01:33.686      python, R and dashboard tools          NaN
# NaT                                                   None          NaN
# NaT                                                   None          NaN
# 2021-06-07 09:37:27.103                 data visualization          NaN
#
#                         Unnamed: 107
# Timestamp
# 2021-06-06 20:49:18.800          NaN
# 2021-06-06 21:01:33.686          NaN
# NaT                              NaN
# NaT                              NaN
# 2021-06-07 09:37:27.103          NaN
#
# [5 rows x 107 columns]

# %%
## data cleaning
## drop from column
df.dropna(axis= 1, how = 'all', inplace= True)
## drop from row
df.dropna(axis= 0, how = 'all', inplace= True)
## replace column value to 1 if 'Check if taken' or ' Check if taken or taking during Term 6 to 8'
df.replace('Check if taken', 1, inplace = True)
df.replace('Check if taken or taking during Term 6 to 8', 1, inplace = True)
df.describe(include ='all')
# Out:
#        Pillar  ESD Focus Track [Aviation]  \
# count      41                         1.0
# unique      2                         NaN
# top       ESD                         NaN
# freq       28                         NaN
# mean      NaN                         1.0
# std       NaN                         NaN
# min       NaN                         1.0
# 25%       NaN                         1.0
# 50%       NaN                         1.0
# 75%       NaN                         1.0
# max       NaN                         1.0
#
#         ESD Focus Track [Business Analytics and Operations Research]  \
# count                                                21.0
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                                  1.0
# std                                                   0.0
# min                                                   1.0
# 25%                                                   1.0
# 50%                                                   1.0
# 75%                                                   1.0
# max                                                   1.0
#
#         ESD Focus Track [Financial Services]  \
# count                                    5.0
# unique                                   NaN
# top                                      NaN
# freq                                     NaN
# mean                                     1.0
# std                                      0.0
# min                                      1.0
# 25%                                      1.0
# 50%                                      1.0
# 75%                                      1.0
# max                                      1.0
#
#         ESD Focus Track [Supply Chain & Logistics]  \
# count                                          2.0
# unique                                         NaN
# top                                            NaN
# freq                                           NaN
# mean                                           1.0
# std                                            0.0
# min                                            1.0
# 25%                                            1.0
# 50%                                            1.0
# 75%                                            1.0
# max                                            1.0
#
#         ESD Focus Track [Urban Infrastructure Systems]  \
# count                                              3.0
# unique                                             NaN
# top                                                NaN
# freq                                               NaN
# mean                                               1.0
# std                                                0.0
# min                                                1.0
# 25%                                                1.0
# 50%                                                1.0
# 75%                                                1.0
# max                                                1.0
#
#         ESD Focus Track [No focus track / Customized focus track]  \
# count                                                 2.0
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                                  1.0
# std                                                   0.0
# min                                                   1.0
# 25%                                                   1.0
# 50%                                                   1.0
# 75%                                                   1.0
# max                                                   1.0
#
#         ISTD Focus Track [AI]  ISTD Focus Track [Data Analytics]  \
# count                     7.0                               10.0
# unique                    NaN                                NaN
# top                       NaN                                NaN
# freq                      NaN                                NaN
# mean                      1.0                                1.0
# std                       0.0                                0.0
# min                       1.0                                1.0
# 25%                       1.0                                1.0
# 50%                       1.0                                1.0
# 75%                       1.0                                1.0
# max                       1.0                                1.0
#
#         ISTD Focus Track [Financial Technology]  ...  \
# count                                       2.0  ...
# unique                                      NaN  ...
# top                                         NaN  ...
# freq                                        NaN  ...
# mean                                        1.0  ...
# std                                         0.0  ...
# min                                         1.0  ...
# 25%                                         1.0  ...
# 50%                                         1.0  ...
# 75%                                         1.0  ...
# max                                         1.0  ...
#
#                01.116 AI for Healthcare (Term 7) (TAE)  \
# count                                                1
# unique                                               1
# top     OpenCV, Computer Vision, Deep Learning, Python
# freq                                                 1
# mean                                               NaN
# std                                                NaN
# min                                                NaN
# 25%                                                NaN
# 50%                                                NaN
# 75%                                                NaN
# max                                                NaN
#
#               01.102 Energy Systems and Management (TAE )  \
# count                                                   4
# unique                                                  4
# top     Optimise the energy having to be traded to ens...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#        01.104 Networked Life (TAE )  01.107 Urban Transportation (TAE )  \
# count                            13                                   2
# unique                           11                                   2
# top                          Python    Aimsun Software and traffic sims
# freq                              3                                   1
# mean                            NaN                                 NaN
# std                             NaN                                 NaN
# min                             NaN                                 NaN
# 25%                             NaN                                 NaN
# 50%                             NaN                                 NaN
# 75%                             NaN                                 NaN
# max                             NaN                                 NaN
#
#                  Other ESD Modules if not listed  \
# count                                          4
# unique                                         4
# top     40.015 Simulation Modelling and Analysis
# freq                                           1
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#                    Other ESD Modules if not listed.1  \
# count                                              1
# unique                                             1
# top     40.015 Simulation Modelling and Analysis, JS
# freq                                               1
# mean                                             NaN
# std                                              NaN
# min                                              NaN
# 25%                                              NaN
# 50%                                              NaN
# 75%                                              NaN
# max                                              NaN
#
#          Other ISTD Modules if not listed  \
# count                                   5
# unique                                  4
# top     50.004 Introduction to Algorithms
# freq                                    2
# mean                                  NaN
# std                                   NaN
# min                                   NaN
# 25%                                   NaN
# 50%                                   NaN
# 75%                                   NaN
# max                                   NaN
#
#                        Other ISTD Modules if not listed.1  \
# count                                                   3
# unique                                                  3
# top     50.004 Introduction to Algorithms - data struc...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#         What are your academic/career interest?  \
# count                                        41
# unique                                       32
# top                                Data Science
# freq                                          5
# mean                                        NaN
# std                                         NaN
# min                                         NaN
# 25%                                         NaN
# 50%                                         NaN
# 75%                                         NaN
# max                                         NaN
#
#         What are your skills of interest?
# count                                  41
# unique                                 30
# top                                Coding
# freq                                    4
# mean                                  NaN
# std                                   NaN
# min                                   NaN
# 25%                                   NaN
# 50%                                   NaN
# 75%                                   NaN
# max                                   NaN
#
# [11 rows x 86 columns]

# %%
import random
random.seed(123)
suveryMerge = df.sample(frac=0.5,random_state=200) #random state is a seed value
suveryFeedbackNValid= df.drop(suveryMerge.index)
suveryFeedback= suveryFeedbackNValid.sample(frac=0.5,random_state=200)
suveryVaild= suveryFeedbackNValid.drop(suveryFeedback.index)

# %%
suveryMerge.head()
# Out:
#                         Pillar  ESD Focus Track [Aviation]  \
# Timestamp
# 2021-06-09 16:22:10.323    ESD                         NaN
# 2021-06-09 14:11:01.465    ESD                         NaN
# 2021-06-09 15:15:29.592   ISTD                         NaN
# 2021-06-09 13:22:25.526    ESD                         NaN
# 2021-06-09 21:23:28.750   ISTD                         NaN
#
#                          ESD Focus Track [Business Analytics and Operations Research]  \
# Timestamp
# 2021-06-09 16:22:10.323                                                1.0
# 2021-06-09 14:11:01.465                                                1.0
# 2021-06-09 15:15:29.592                                                NaN
# 2021-06-09 13:22:25.526                                                1.0
# 2021-06-09 21:23:28.750                                                NaN
#
#                          ESD Focus Track [Financial Services]  \
# Timestamp
# 2021-06-09 16:22:10.323                                   NaN
# 2021-06-09 14:11:01.465                                   NaN
# 2021-06-09 15:15:29.592                                   NaN
# 2021-06-09 13:22:25.526                                   NaN
# 2021-06-09 21:23:28.750                                   NaN
#
#                          ESD Focus Track [Supply Chain & Logistics]  \
# Timestamp
# 2021-06-09 16:22:10.323                                         NaN
# 2021-06-09 14:11:01.465                                         NaN
# 2021-06-09 15:15:29.592                                         NaN
# 2021-06-09 13:22:25.526                                         NaN
# 2021-06-09 21:23:28.750                                         NaN
#
#                          ESD Focus Track [Urban Infrastructure Systems]  \
# Timestamp
# 2021-06-09 16:22:10.323                                             NaN
# 2021-06-09 14:11:01.465                                             NaN
# 2021-06-09 15:15:29.592                                             NaN
# 2021-06-09 13:22:25.526                                             NaN
# 2021-06-09 21:23:28.750                                             NaN
#
#                          ESD Focus Track [No focus track / Customized focus track]  \
# Timestamp
# 2021-06-09 16:22:10.323                                                NaN
# 2021-06-09 14:11:01.465                                                NaN
# 2021-06-09 15:15:29.592                                                NaN
# 2021-06-09 13:22:25.526                                                NaN
# 2021-06-09 21:23:28.750                                                NaN
#
#                          ISTD Focus Track [AI]  \
# Timestamp
# 2021-06-09 16:22:10.323                    1.0
# 2021-06-09 14:11:01.465                    NaN
# 2021-06-09 15:15:29.592                    NaN
# 2021-06-09 13:22:25.526                    NaN
# 2021-06-09 21:23:28.750                    NaN
#
#                          ISTD Focus Track [Data Analytics]  \
# Timestamp
# 2021-06-09 16:22:10.323                                1.0
# 2021-06-09 14:11:01.465                                NaN
# 2021-06-09 15:15:29.592                                NaN
# 2021-06-09 13:22:25.526                                NaN
# 2021-06-09 21:23:28.750                                1.0
#
#                          ISTD Focus Track [Financial Technology]  ...  \
# Timestamp                                                         ...
# 2021-06-09 16:22:10.323                                      NaN  ...
# 2021-06-09 14:11:01.465                                      NaN  ...
# 2021-06-09 15:15:29.592                                      NaN  ...
# 2021-06-09 13:22:25.526                                      NaN  ...
# 2021-06-09 21:23:28.750                                      NaN  ...
#
#                          01.116 AI for Healthcare (Term 7) (TAE)  \
# Timestamp
# 2021-06-09 16:22:10.323                                      NaN
# 2021-06-09 14:11:01.465                                      NaN
# 2021-06-09 15:15:29.592                                      NaN
# 2021-06-09 13:22:25.526                                      NaN
# 2021-06-09 21:23:28.750                                      NaN
#
#                          01.102 Energy Systems and Management (TAE )  \
# Timestamp
# 2021-06-09 16:22:10.323                                          NaN
# 2021-06-09 14:11:01.465                                          NaN
# 2021-06-09 15:15:29.592                                          NaN
# 2021-06-09 13:22:25.526                                          NaN
# 2021-06-09 21:23:28.750                                          NaN
#
#                         01.104 Networked Life (TAE )  \
# Timestamp
# 2021-06-09 16:22:10.323                          Rbm
# 2021-06-09 14:11:01.465                          NaN
# 2021-06-09 15:15:29.592                          NaN
# 2021-06-09 13:22:25.526                          NaN
# 2021-06-09 21:23:28.750                          NaN
#
#                          01.107 Urban Transportation (TAE )  \
# Timestamp
# 2021-06-09 16:22:10.323                                 NaN
# 2021-06-09 14:11:01.465                                 NaN
# 2021-06-09 15:15:29.592                                 NaN
# 2021-06-09 13:22:25.526                                 NaN
# 2021-06-09 21:23:28.750                                 NaN
#
#                          Other ESD Modules if not listed  \
# Timestamp
# 2021-06-09 16:22:10.323                    Intro to algo
# 2021-06-09 14:11:01.465                              NaN
# 2021-06-09 15:15:29.592                              NaN
# 2021-06-09 13:22:25.526                              NaN
# 2021-06-09 21:23:28.750                              NaN
#
#                          Other ESD Modules if not listed.1  \
# Timestamp
# 2021-06-09 16:22:10.323                                NaN
# 2021-06-09 14:11:01.465                                NaN
# 2021-06-09 15:15:29.592                                NaN
# 2021-06-09 13:22:25.526                                NaN
# 2021-06-09 21:23:28.750                                NaN
#
#                          Other ISTD Modules if not listed  \
# Timestamp
# 2021-06-09 16:22:10.323                               NaN
# 2021-06-09 14:11:01.465                               NaN
# 2021-06-09 15:15:29.592                               NaN
# 2021-06-09 13:22:25.526                               NaN
# 2021-06-09 21:23:28.750                               NaN
#
#                          Other ISTD Modules if not listed.1  \
# Timestamp
# 2021-06-09 16:22:10.323                                 NaN
# 2021-06-09 14:11:01.465                                 NaN
# 2021-06-09 15:15:29.592                                 NaN
# 2021-06-09 13:22:25.526                                 NaN
# 2021-06-09 21:23:28.750                                 NaN
#
#                          What are your academic/career interest?  \
# Timestamp
# 2021-06-09 16:22:10.323                           Data analytics
# 2021-06-09 14:11:01.465                     software engineering
# 2021-06-09 15:15:29.592                                 Cybersec
# 2021-06-09 13:22:25.526                                     Math
# 2021-06-09 21:23:28.750                               Technology
#
#                          What are your skills of interest?
# Timestamp
# 2021-06-09 16:22:10.323                             Coding
# 2021-06-09 14:11:01.465                             python
# 2021-06-09 15:15:29.592                        Programming
# 2021-06-09 13:22:25.526                 data visualization
# 2021-06-09 21:23:28.750                            web dev
#
# [5 rows x 86 columns]

# %% [markdown]
# # Formatting the dataset

# %%
def obtainingElectives(_df):
    print('Starting to obtain dict of electives')
    electiveDict = {}
    for columnName in _df.columns:
        if 'Elective Modules taken or taking' in columnName:
            openSquareBracket = columnName.find('[') + 1
            closeSquareBracket = columnName.find(']')
            electiveDict[columnName] = columnName[openSquareBracket:closeSquareBracket]
    return(electiveDict)

# %%
def updatingdict(_df,electiveWordsDict,key):
    key = str(key)
    ## if there is no word in columnname
    if key not in electiveWordsDict.keys():
        electiveWordsDict[key] = len(_df)
    else:
        electiveWordsDict[key] = electiveWordsDict[key] + len(_df)
    return(electiveWordsDict)

# %%
def obtainingDetailsFromPillar(_df,electiveWordsDict,columnOfInterest):
    ## filtering the _df
    pillarDf = _df.copy(deep = False)
    print('Obtaining from "{}" column'.format(columnOfInterest))
    ## number of times the word/skills appears
    for pillar in pillarDf[columnOfInterest].unique():
        singlePillarDf = pillarDf[pillarDf[columnOfInterest] == pillar]
        electiveWordsDict =  updatingdict(singlePillarDf,electiveWordsDict,pillar)
    return(electiveWordsDict)

# %%
def obtainingDetailsFromTrack(_df,electiveWordsDict,columnOfInterest):
    print('Obtaining from "{}" column'.format(columnOfInterest))
    for columnName in _df.columns:
    ## ensure a part of the columns name contains the columnOfInterest
        if columnOfInterest in columnName:
    ## filtered df
            singleTrackDf = _df[_df[columnName] == 1]
    ## finding the index of []
            openSquareBracket = columnName.find('[') + 1
            closeSquareBracket = columnName.find(']')
    ## if the columnName does not have bracket then do not shorten the columnName
            if (openSquareBracket > 0) & (closeSquareBracket > 0):
                columnName = columnName[openSquareBracket:closeSquareBracket]
    ## number of times the word/skills appears
            electiveWordsDict =  updatingdict(singleTrackDf,electiveWordsDict,columnName)
    return(electiveWordsDict)

# %%
def textCleaning(s):
    ## spacy tutorial https://www.analyticsvidhya.com/blog/2020/03/spacy-tutorial-learn-natural-language-processing/

    import json
    import string
    from sklearn.feature_extraction.text import TfidfVectorizer
    import pandas as pd
    from gensim.parsing.preprocessing import remove_stopwords
    import nltk
    from nltk.stem import WordNetLemmatizer
    from nltk.corpus import wordnet
    import numpy as np

    lemmatizer = WordNetLemmatizer()
    def get_wordnet_pos(word):
        """Map POS tag to first character lemmatize() accepts"""
        tag = nltk.pos_tag([word])[0][1][0].upper()
        tag_dict = {"J": wordnet.ADJ,
                    "N": wordnet.NOUN,
                    "V": wordnet.VERB,
                    "R": wordnet.ADV}

        return tag_dict.get(tag, wordnet.NOUN)

    s = str(np.char.lower(s))
    s = ''.join([i for i in s if not i.isdigit()])
    s = remove_stopwords(s)
    s = [lemmatizer.lemmatize(w, get_wordnet_pos(w)) for w in nltk.word_tokenize(s)]
    s = ' '.join([str(elem) for elem in s])
    s = s.translate(str.maketrans('','',string.punctuation))
    s = s.split()
    return(s)

# %%
def obtainingDetailsFromNonNumericalColumnOfInterest(_df,electiveWordsDict,columnOfInterest):
    print('Obtaining from "{}" column'.format(columnOfInterest))
    ## filter by those elective or columns which shows skills or interest
    df = _df.copy(deep = False)
    df = df[columnOfInterest]
    df.dropna(axis= 0, how = 'all', inplace= True)
    for skillOrInterest in df:
        skillOrInterest = textCleaning(skillOrInterest)
        print(skillOrInterest)
    ## number of times the word/skills appears
    ## just use a df of length 1 as we are checking one row of entry at a time
        dfOfLength1 = df.head(1)
        for word in skillOrInterest:
            electiveWordsDict = updatingdict(dfOfLength1,electiveWordsDict,word)
    return(electiveWordsDict)

# %%
def formattingSurveyData(_df):
    df = _df.copy(deep = False)
    ## obtainig electives names from suvery
    electiveDict = obtainingElectives(df)
    ## dict to store the words from suvery about all elective
    allElectiveDict = {}
    ## iterate through the electives
    for k,v in electiveDict.items():
    ## filter by electives
        electiveDf = df[df[k] == 1]
    ## dict to store the words from suvery about all elective
        electiveWordsDict = {}
        print('\n')
    ## check the pillar, focus track, skills, interest and knowledge gain that are remaining after filtering
    ## count the occurances of them happening
    ## convert the those into words to be index of the rows (including elective name)
        pillar = obtainingDetailsFromPillar(electiveDf,electiveWordsDict,'Pillar')
        focusTrack = obtainingDetailsFromTrack(electiveDf,electiveWordsDict,'Focus Track')
        skillsFromEachElective = obtainingDetailsFromNonNumericalColumnOfInterest(electiveDf,electiveWordsDict,v)
    ## add to the overall
        allElectiveDict[v] = electiveWordsDict
    return(allElectiveDict)

# %%
formattingSurveyDataDict = formattingSurveyData(suveryMerge)
formattingSurveyDataDict
# Out:
# Starting to obtain dict of electives
#
#
# Obtaining from "Pillar" column
# Obtaining from "Focus Track" column
# Obtaining from "40.240 Investment Science" column
# ['capm']
# ['perform', 'valuation', 'share', 'balance', 'sheet', 'feel', 'skill', 'easily', 'forgetable', 'involves', 'math', 'equation', 'wouldnt', 'remember', 'field']
# ['learnt', 'basic', 'stock', 'market', 'stock', 'analyze', 'write', 'stock', 'pitch']
# ['capm', 'stock', 'pricing']
#
#
# Obtaining from "Pillar" column
# Obtaining from "Focus Track" column
# Obtaining from "40.242 Derivative Pricing and Risk Management" column
# ['arbitrage']
# ['learnt', 'derivative', 'use', 'hedge', 'stock', 'balance', 'risk']
# ['python', 'option', 'pricing', 'hedge', 'monte', 'carlo', 'simulation', 'blackscholes', 'excel']
# ['black', 'scholes', 'option', 'pricing', 'rate']
#
#
# Obtaining from "Pillar" column
# Obtaining from "Focus Track" column
# Obtaining from "40.260 Supply Chain Management" column
# ['excel', 'linear', 'program', 'heuristic']
#
#
# Obtaining from "Pillar" column
# Obtaining from "Focus Track" column
# Obtaining from "40.302 Advanced Optim/ 40.305 Advanced Stochastic" column
# ['gurobi']
#
#
# Obtaining from "Pillar" column
# Obtaining from "Focus Track" column
# Obtaining from "40.316 Game Theory" column
# ['nash', 'eqbm']
# ['model', 'day', 'day', 'interaction', 'business', 'operatios', 'political', 'campaign', 'game', 'game', 'decide', 'nash', 'equilibrium', 'outcome', 'lot', 'assumption', 'involve', 'hit', 'ne', 'particular', 'moblab', 'game', 'rig', 'winnable', 'luck', 'player', 'equally', 'smart', 'want', 'social', 'optimum', 'outcome', 'selfish', 'player', 'screw', 'team']
# ['learn', 'consider', 'perspective', 'people', 'decide', 'give', 'rationale', 'chocies']
# ['strategic', 'think', 'logic']
# ['formulate', 'nash', 'equilibrium']
# ['nash', 'equilibrium']
#
#
# Obtaining from "Pillar" column
# Obtaining from "Focus Track" column
# Obtaining from "40.317 Financial Systems Design" column
# ['learn', 'design', 'simple', 'financial', 'python', 'package']
# ['python', 'zeromq', 'trading', 'game', 'multithreading']
# ['zeromq', 'server']
#
#
# Obtaining from "Pillar" column
# Obtaining from "Focus Track" column
# Obtaining from "40.318 Supply Chain Digitalisation and Design" column
#
#
# Obtaining from "Pillar" column
# Obtaining from "Focus Track" column
# Obtaining from "40.319 Statistical and Machine Learning" column
# ['python']
# ['regression']
# ['python', 'pytorch']
# ['hmm']
# ['alot', 'theory', 'which', 'forgot', 'love', 'nd', 'half', 'class', 'well', 'youtube', 'jk', 'nd', 'half', 'digestable', 'wide', 'real', 'world', 'application', 'have', 'favourite', 'topic', 'multiarmed', 'bandit', 'expose', 'concept', 'reinforcement', 'learn', 'capstone']
# ['learnt', 'machine', 'learn', 'deep', 'learn', 'implement', 'python', 'package']
# ['element', 'statistical', 'learn', 'pytorch']
# ['different', 'type', 'learn', 'algorithm']
# ['python']
# ['pytorch']
# ['python', 'pytorch']
#
#
# Obtaining from "Pillar" column
# Obtaining from "Focus Track" column
# Obtaining from "40.320 Airport Systems Planning and Design" column
#
#
# Obtaining from "Pillar" column
# Obtaining from "Focus Track" column
# Obtaining from "40.321 Airport Systems Modelling and Simulation" column
#
#
# Obtaining from "Pillar" column
# Obtaining from "Focus Track" column
# Obtaining from "40.323 Equity Valuation" column
# ['financial', 'model']
#
#
# Obtaining from "Pillar" column
# Obtaining from "Focus Track" column
# Obtaining from "40.324 Fundamentals of Investing" column
# ['financial', 'statement', 'accounting', 'stock', 'pitch', 'arbitrage', 'pricing', 'bond', 'pricing']
#
#
# Obtaining from "Pillar" column
# Obtaining from "Focus Track" column
# Obtaining from "50.006 User Interface Design and Implementation" column
# ['wireframing', 'ui', 'evaluation', 'prototyping', 'user', 'analysis']
# ['design', 'uiux', 'figma', 'prototyping', 'work', 'annoy', 'teammate', 'ui', 'design', 'heuristic']
# ['soft', 'design', 'user', 'experience', 'user', 'interview']
#
#
# Obtaining from "Pillar" column
# Obtaining from "Focus Track" column
# Obtaining from "50.007 Machine Learning" column
# ['learn', 'useful', 'learnt', 'ml']
# ['perceptron', 'cnn']
# ['python']
# ['machine', 'learn', 'algorithm', 'implementation', 'python']
# ['python']
# ['python', 'machine', 'learn', 'algorithm']
# ['python', 'neural', 'network']
# ['machine', 'learn', 'cod', 'math']
#
#
# Obtaining from "Pillar" column
# Obtaining from "Focus Track" column
# Obtaining from "50.017 Graphics and Visualisation" column
# ['model', 'render', 'graphical', 'model', 'opengl', 'c', 'learn', 'math', 'shape', 'model', 'perform', 'mapping', 'different', 'dimension', 'eg', 'd', 'd']
#
#
# Obtaining from "Pillar" column
# Obtaining from "Focus Track" column
# Obtaining from "50.020 Network Security" column
# ['learnt', 'secure', 'network', 'stack', 'actually', 'learnt', 'lot', 'network', 'work', 'large']
#
#
# Obtaining from "Pillar" column
# Obtaining from "Focus Track" column
# Obtaining from "50.021 Artificial Intelligence" column
# ['dfs']
# ['ai', 'think']
# ['ai', 'algorithm']
# ['python', 'search', 'algo']
# ['construction', 'development', 'ai']
# ['python', 'search', 'algorithm']
# ['search', 'algorithm']
# ['python', 'search', 'algorithm']
# ['python']
# ['python', 'search', 'algorithm']
#
#
# Obtaining from "Pillar" column
# Obtaining from "Focus Track" column
# Obtaining from "50.033 Foundations of Game Design and Development" column
# ['unity', 'c']
# ['unity', 'game', 'development', 'history', 'game', 'game', 'design', 'element']
# ['c', 'unity', 'game', 'design']
#
#
# Obtaining from "Pillar" column
# Obtaining from "Focus Track" column
# Obtaining from " 50.035 Computer Vision" column
# ['edge', 'detection', 'filter']
# ['python', 'opencv', 'kera', 'tensorflow']
# ['python', 'opencv', 'tensorflow', 'kera']
# ['pytorch', 'kera', 'cnn']
# ['convolution', 'neural', 'network', 'kera', 'python', 'yolo', 'detection', 'classification', 'darknet']
#
#
# Obtaining from "Pillar" column
# Obtaining from "Focus Track" column
# Obtaining from "50.037 Blockchain Technology" column
# ['learn', 'cryptocurrency', 'smart', 'contract']
# ['bitcoin', 'blockchain', 'distribute', 'system', 'encryption']
#
#
# Obtaining from "Pillar" column
# Obtaining from "Focus Track" column
# Obtaining from "50.038 Computational Data Science" column
# ['data', 'visualization', 'cnn']
# ['library', 'kera']
# ['python', 'kera']
# ['kera']
# ['classification', 'kera', 'python', 'scikitlearn', 'data', 'visualisation']
# ['electronics', 'ic', 'chip', 'jsim', 'appreciation', 'modern', 'compute', 'hardware']
#
#
# Obtaining from "Pillar" column
# Obtaining from "Focus Track" column
# Obtaining from "50.039 Theory and Practice of Deep Learning" column
# ['python', 'pytorch']
# ['pytorch']
# ['python', 'pytorch', 'recurrent', 'neural', 'network', 'convolution', 'neural', 'network', 'initialisation', 'dataloader', 'data', 'visualisation']
# ['python', 'pytorch']
#
#
# Obtaining from "Pillar" column
# Obtaining from "Focus Track" column
# Obtaining from "50.040 Natural Language Processing" column
# ['nlp']
# ['nlp', 'cod', 'python', 'data', 'management']
# ['python', 'nltk', 'pytorch']
#
#
# Obtaining from "Pillar" column
# Obtaining from "Focus Track" column
# Obtaining from "50.041 Distributed Systems and Computing" column
# ['learnt', 'pain', 'ensure', 'consistency', 'fault', 'tolerance']
# ['java', 'software', 'development', 'teamwork']
#
#
# Obtaining from "Pillar" column
# Obtaining from "Focus Track" column
# Obtaining from "50.042 Foundations of Cybersecurity" column
# ['learn', 'crypto']
#
#
# Obtaining from "Pillar" column
# Obtaining from "Focus Track" column
# Obtaining from "50.043 Database Systems / Database and Big Data Systems (for class 2021)" column
# ['learn', 'devops']
# ['relational', 'algebra']
# ['mysql', 'mongodb', 'flask', 'reactjs', 'hadoop', 'spark']
# ['intro', 'aws', 'cloud', 'service', 'sql', 'sql']
# ['python', 'hadoop', 'mapreduce', 'pyspark', 'mysql']
# ['sql', 'mongodb', 'hadoop', 'spark', 'map', 'reduce']
# ['python', 'javascript', 'sql', 'nosql', 'mongo', 'aws', 's', 'ec', 'react', 'node', 'automation', 'script']
# ['database', 'web', 'development', 'mysql', 'mongodb', 'javascript', 'aws']
#
#
# Obtaining from "Pillar" column
# Obtaining from "Focus Track" column
# Obtaining from "50.044 System Security" column
# ['learn', 'reverse', 'engineering', 'far']
#
#
# Obtaining from "Pillar" column
# Obtaining from "Focus Track" column
# Obtaining from "50.045 Information Retrieval" column
# ['implementation']
# ['python']
# ['python', 'pytorch', 'sklearn']
# ['document', 'rank', 'tfidf']
# ['python', 'tfidf', 'embed', 'matrix', 'index']
#
#
# Obtaining from "Pillar" column
# Obtaining from "Focus Track" column
# Obtaining from "50.046 Cloud Computing and Internet of Things" column
# ['iot', 'electronics', 'aws', 'esp', 'raspberry', 'pi']
# {'40.240 Investment Science': {'ESD': 4,
#   'Aviation': 0,
#   'Business Analytics and Operations Research': 3,
#   'Financial Services': 3,
#   'Supply Chain & Logistics': 0,
#   'Urban Infrastructure Systems': 0,
#   'No focus track / Customized focus track': 0,
#   'AI': 0,
#   'Data Analytics': 0,
#   'Financial Technology': 0,
#   'Security': 0,
#   'Others': 0,
#   'capm': 2,
#   'perform': 1,
#   'valuation': 1,
#   'share': 1,
#   'balance': 1,
#   'sheet': 1,
#   'feel': 1,
#   'skill': 1,
#   'easily': 1,
#   'forgetable': 1,
#   'involves': 1,
#   'math': 1,
#   'equation': 1,
#   'wouldnt': 1,
#   'remember': 1,
#   'field': 1,
#   'learnt': 1,
#   'basic': 1,
#   'stock': 4,
#   'market': 1,
#   'analyze': 1,
#   'write': 1,
#   'pitch': 1,
#   'pricing': 1},
#  '40.242 Derivative Pricing and Risk Management': {'ESD': 3,
#   'ISTD': 1,
#   'Aviation': 0,
#   'Business Analytics and Operations Research': 2,
#   'Financial Services': 3,
#   'Supply Chain & Logistics': 0,
#   'Urban Infrastructure Systems': 0,
#   'No focus track / Customized focus track': 0,
#   'AI': 0,
#   'Data Analytics': 0,
#   'Financial Technology': 1,
#   'Security': 0,
#   'Others': 0,
#   'arbitrage': 1,
#   'learnt': 1,
#   'derivative': 1,
#   'use': 1,
#   'hedge': 2,
#   'stock': 1,
#   'balance': 1,
#   'risk': 1,
#   'python': 1,
#   'option': 2,
#   'pricing': 2,
#   'monte': 1,
#   'carlo': 1,
#   'simulation': 1,
#   'blackscholes': 1,
#   'excel': 1,
#   'black': 1,
#   'scholes': 1,
#   'rate': 1},
#  '40.260 Supply Chain Management': {'ESD': 2,
#   'Aviation': 0,
#   'Business Analytics and Operations Research': 1,
#   'Financial Services': 0,
#   'Supply Chain & Logistics': 0,
#   'Urban Infrastructure Systems': 0,
#   'No focus track / Customized focus track': 1,
#   'AI': 0,
#   'Data Analytics': 0,
#   'Financial Technology': 0,
#   'Security': 0,
#   'Others': 0,
#   'excel': 1,
#   'linear': 1,
#   'program': 1,
#   'heuristic': 1},
#  '40.302 Advanced Optim/ 40.305 Advanced Stochastic': {'ESD': 1,
#   'Aviation': 0,
#   'Business Analytics and Operations Research': 1,
#   'Financial Services': 0,
#   'Supply Chain & Logistics': 0,
#   'Urban Infrastructure Systems': 0,
#   'No focus track / Customized focus track': 0,
#   'AI': 0,
#   'Data Analytics': 0,
#   'Financial Technology': 0,
#   'Security': 0,
#   'Others': 0,
#   'gurobi': 1},
#  '40.316 Game Theory': {'ESD': 10,
#   'Aviation': 0,
#   'Business Analytics and Operations Research': 10,
#   'Financial Services': 2,
#   'Supply Chain & Logistics': 0,
#   'Urban Infrastructure Systems': 0,
#   'No focus track / Customized focus track': 0,
#   'AI': 1,
#   'Data Analytics': 1,
#   'Financial Technology': 0,
#   'Security': 0,
#   'Others': 0,
#   'nash': 4,
#   'eqbm': 1,
#   'model': 1,
#   'day': 2,
#   'interaction': 1,
#   'business': 1,
#   'operatios': 1,
#   'political': 1,
#   'campaign': 1,
#   'game': 3,
#   'decide': 2,
#   'equilibrium': 3,
#   'outcome': 2,
#   'lot': 1,
#   'assumption': 1,
#   'involve': 1,
#   'hit': 1,
#   'ne': 1,
#   'particular': 1,
#   'moblab': 1,
#   'rig': 1,
#   'winnable': 1,
#   'luck': 1,
#   'player': 2,
#   'equally': 1,
#   'smart': 1,
#   'want': 1,
#   'social': 1,
#   'optimum': 1,
#   'selfish': 1,
#   'screw': 1,
#   'team': 1,
#   'learn': 1,
#   'consider': 1,
#   'perspective': 1,
#   'people': 1,
#   'give': 1,
#   'rationale': 1,
#   'chocies': 1,
#   'strategic': 1,
#   'think': 1,
#   'logic': 1,
#   'formulate': 1},
#  '40.317 Financial Systems Design': {'ESD': 2,
#   'ISTD': 1,
#   'Aviation': 0,
#   'Business Analytics and Operations Research': 2,
#   'Financial Services': 2,
#   'Supply Chain & Logistics': 0,
#   'Urban Infrastructure Systems': 0,
#   'No focus track / Customized focus track': 0,
#   'AI': 0,
#   'Data Analytics': 0,
#   'Financial Technology': 1,
#   'Security': 0,
#   'Others': 0,
#   'learn': 1,
#   'design': 1,
#   'simple': 1,
#   'financial': 1,
#   'python': 2,
#   'package': 1,
#   'zeromq': 2,
#   'trading': 1,
#   'game': 1,
#   'multithreading': 1,
#   'server': 1},
#  '40.318 Supply Chain Digitalisation and Design': {'Aviation': 0,
#   'Business Analytics and Operations Research': 0,
#   'Financial Services': 0,
#   'Supply Chain & Logistics': 0,
#   'Urban Infrastructure Systems': 0,
#   'No focus track / Customized focus track': 0,
#   'AI': 0,
#   'Data Analytics': 0,
#   'Financial Technology': 0,
#   'Security': 0,
#   'Others': 0},
#  '40.319 Statistical and Machine Learning': {'ESD': 12,
#   'Aviation': 0,
#   'Business Analytics and Operations Research': 10,
#   'Financial Services': 3,
#   'Supply Chain & Logistics': 0,
#   'Urban Infrastructure Systems': 0,
#   'No focus track / Customized focus track': 1,
#   'AI': 1,
#   'Data Analytics': 1,
#   'Financial Technology': 0,
#   'Security': 0,
#   'Others': 0,
#   'python': 5,
#   'regression': 1,
#   'pytorch': 4,
#   'hmm': 1,
#   'alot': 1,
#   'theory': 1,
#   'which': 1,
#   'forgot': 1,
#   'love': 1,
#   'nd': 2,
#   'half': 2,
#   'class': 1,
#   'well': 1,
#   'youtube': 1,
#   'jk': 1,
#   'digestable': 1,
#   'wide': 1,
#   'real': 1,
#   'world': 1,
#   'application': 1,
#   'have': 1,
#   'favourite': 1,
#   'topic': 1,
#   'multiarmed': 1,
#   'bandit': 1,
#   'expose': 1,
#   'concept': 1,
#   'reinforcement': 1,
#   'learn': 5,
#   'capstone': 1,
#   'learnt': 1,
#   'machine': 1,
#   'deep': 1,
#   'implement': 1,
#   'package': 1,
#   'element': 1,
#   'statistical': 1,
#   'different': 1,
#   'type': 1,
#   'algorithm': 1},
#  '40.320 Airport Systems Planning and Design': {'Aviation': 0,
#   'Business Analytics and Operations Research': 0,
#   'Financial Services': 0,
#   'Supply Chain & Logistics': 0,
#   'Urban Infrastructure Systems': 0,
#   'No focus track / Customized focus track': 0,
#   'AI': 0,
#   'Data Analytics': 0,
#   'Financial Technology': 0,
#   'Security': 0,
#   'Others': 0},
#  '40.321 Airport Systems Modelling and Simulation': {'Aviation': 0,
#   'Business Analytics and Operations Research': 0,
#   'Financial Services': 0,
#   'Supply Chain & Logistics': 0,
#   'Urban Infrastructure Systems': 0,
#   'No focus track / Customized focus track': 0,
#   'AI': 0,
#   'Data Analytics': 0,
#   'Financial Technology': 0,
#   'Security': 0,
#   'Others': 0},
#  '40.323 Equity Valuation': {'ESD': 1,
#   'Aviation': 0,
#   'Business Analytics and Operations Research': 0,
#   'Financial Services': 1,
#   'Supply Chain & Logistics': 0,
#   'Urban Infrastructure Systems': 0,
#   'No focus track / Customized focus track': 0,
#   'AI': 0,
#   'Data Analytics': 0,
#   'Financial Technology': 0,
#   'Security': 0,
#   'Others': 0,
#   'financial': 1,
#   'model': 1},
#  '40.324 Fundamentals of Investing': {'ISTD': 1,
#   'Aviation': 0,
#   'Business Analytics and Operations Research': 0,
#   'Financial Services': 0,
#   'Supply Chain & Logistics': 0,
#   'Urban Infrastructure Systems': 0,
#   'No focus track / Customized focus track': 0,
#   'AI': 0,
#   'Data Analytics': 0,
#   'Financial Technology': 1,
#   'Security': 0,
#   'Others': 0,
#   'financial': 1,
#   'statement': 1,
#   'accounting': 1,
#   'stock': 1,
#   'pitch': 1,
#   'arbitrage': 1,
#   'pricing': 2,
#   'bond': 1},
#  '50.006 User Interface Design and Implementation': {'ISTD': 3,
#   'Aviation': 0,
#   'Business Analytics and Operations Research': 0,
#   'Financial Services': 0,
#   'Supply Chain & Logistics': 0,
#   'Urban Infrastructure Systems': 0,
#   'No focus track / Customized focus track': 0,
#   'AI': 0,
#   'Data Analytics': 3,
#   'Financial Technology': 0,
#   'Security': 0,
#   'Others': 0,
#   'wireframing': 1,
#   'ui': 2,
#   'evaluation': 1,
#   'prototyping': 2,
#   'user': 3,
#   'analysis': 1,
#   'design': 3,
#   'uiux': 1,
#   'figma': 1,
#   'work': 1,
#   'annoy': 1,
#   'teammate': 1,
#   'heuristic': 1,
#   'soft': 1,
#   'experience': 1,
#   'interview': 1},
#  '50.007 Machine Learning': {'ISTD': 8,
#   'Aviation': 0,
#   'Business Analytics and Operations Research': 0,
#   'Financial Services': 0,
#   'Supply Chain & Logistics': 0,
#   'Urban Infrastructure Systems': 0,
#   'No focus track / Customized focus track': 0,
#   'AI': 2,
#   'Data Analytics': 6,
#   'Financial Technology': 1,
#   'Security': 1,
#   'Others': 0,
#   'learn': 4,
#   'useful': 1,
#   'learnt': 1,
#   'ml': 1,
#   'perceptron': 1,
#   'cnn': 1,
#   'python': 5,
#   'machine': 3,
#   'algorithm': 2,
#   'implementation': 1,
#   'neural': 1,
#   'network': 1,
#   'cod': 1,
#   'math': 1},
#  '50.017 Graphics and Visualisation': {'ISTD': 1,
#   'Aviation': 0,
#   'Business Analytics and Operations Research': 0,
#   'Financial Services': 0,
#   'Supply Chain & Logistics': 0,
#   'Urban Infrastructure Systems': 0,
#   'No focus track / Customized focus track': 0,
#   'AI': 0,
#   'Data Analytics': 1,
#   'Financial Technology': 0,
#   'Security': 0,
#   'Others': 0,
#   'model': 3,
#   'render': 1,
#   'graphical': 1,
#   'opengl': 1,
#   'c': 1,
#   'learn': 1,
#   'math': 1,
#   'shape': 1,
#   'perform': 1,
#   'mapping': 1,
#   'different': 1,
#   'dimension': 1,
#   'eg': 1,
#   'd': 2},
#  '50.020 Network Security': {'ISTD': 1,
#   'Aviation': 0,
#   'Business Analytics and Operations Research': 0,
#   'Financial Services': 0,
#   'Supply Chain & Logistics': 0,
#   'Urban Infrastructure Systems': 0,
#   'No focus track / Customized focus track': 0,
#   'AI': 0,
#   'Data Analytics': 0,
#   'Financial Technology': 0,
#   'Security': 1,
#   'Others': 0,
#   'learnt': 2,
#   'secure': 1,
#   'network': 2,
#   'stack': 1,
#   'actually': 1,
#   'lot': 1,
#   'work': 1,
#   'large': 1},
#  '50.021 Artificial Intelligence': {'ESD': 8,
#   'ISTD': 4,
#   'Aviation': 0,
#   'Business Analytics and Operations Research': 6,
#   'Financial Services': 1,
#   'Supply Chain & Logistics': 0,
#   'Urban Infrastructure Systems': 0,
#   'No focus track / Customized focus track': 1,
#   'AI': 3,
#   'Data Analytics': 5,
#   'Financial Technology': 0,
#   'Security': 0,
#   'Others': 0,
#   'dfs': 1,
#   'ai': 3,
#   'think': 1,
#   'algorithm': 5,
#   'python': 5,
#   'search': 5,
#   'algo': 1,
#   'construction': 1,
#   'development': 1},
#  '50.033 Foundations of Game Design and Development': {'ISTD': 4,
#   'Aviation': 0,
#   'Business Analytics and Operations Research': 0,
#   'Financial Services': 0,
#   'Supply Chain & Logistics': 0,
#   'Urban Infrastructure Systems': 0,
#   'No focus track / Customized focus track': 0,
#   'AI': 0,
#   'Data Analytics': 3,
#   'Financial Technology': 1,
#   'Security': 0,
#   'Others': 0,
#   'unity': 3,
#   'c': 2,
#   'game': 4,
#   'development': 1,
#   'history': 1,
#   'design': 2,
#   'element': 1},
#  ' 50.035 Computer Vision': {'ISTD': 5,
#   'Aviation': 0,
#   'Business Analytics and Operations Research': 0,
#   'Financial Services': 0,
#   'Supply Chain & Logistics': 0,
#   'Urban Infrastructure Systems': 0,
#   'No focus track / Customized focus track': 0,
#   'AI': 2,
#   'Data Analytics': 4,
#   'Financial Technology': 1,
#   'Security': 0,
#   'Others': 0,
#   'edge': 1,
#   'detection': 2,
#   'filter': 1,
#   'python': 3,
#   'opencv': 2,
#   'kera': 4,
#   'tensorflow': 2,
#   'pytorch': 1,
#   'cnn': 1,
#   'convolution': 1,
#   'neural': 1,
#   'network': 1,
#   'yolo': 1,
#   'classification': 1,
#   'darknet': 1},
#  '50.037 Blockchain Technology': {'ISTD': 2,
#   'Aviation': 0,
#   'Business Analytics and Operations Research': 0,
#   'Financial Services': 0,
#   'Supply Chain & Logistics': 0,
#   'Urban Infrastructure Systems': 0,
#   'No focus track / Customized focus track': 0,
#   'AI': 0,
#   'Data Analytics': 1,
#   'Financial Technology': 0,
#   'Security': 1,
#   'Others': 0,
#   'learn': 1,
#   'cryptocurrency': 1,
#   'smart': 1,
#   'contract': 1,
#   'bitcoin': 1,
#   'blockchain': 1,
#   'distribute': 1,
#   'system': 1,
#   'encryption': 1},
#  '50.038 Computational Data Science': {'ISTD': 6,
#   'Aviation': 0,
#   'Business Analytics and Operations Research': 0,
#   'Financial Services': 0,
#   'Supply Chain & Logistics': 0,
#   'Urban Infrastructure Systems': 0,
#   'No focus track / Customized focus track': 0,
#   'AI': 2,
#   'Data Analytics': 6,
#   'Financial Technology': 0,
#   'Security': 0,
#   'Others': 0,
#   'data': 2,
#   'visualization': 1,
#   'cnn': 1,
#   'library': 1,
#   'kera': 4,
#   'python': 2,
#   'classification': 1,
#   'scikitlearn': 1,
#   'visualisation': 1,
#   'electronics': 1,
#   'ic': 1,
#   'chip': 1,
#   'jsim': 1,
#   'appreciation': 1,
#   'modern': 1,
#   'compute': 1,
#   'hardware': 1},
#  '50.039 Theory and Practice of Deep Learning': {'ISTD': 3,
#   'ESD': 1,
#   'Aviation': 0,
#   'Business Analytics and Operations Research': 0,
#   'Financial Services': 0,
#   'Supply Chain & Logistics': 0,
#   'Urban Infrastructure Systems': 0,
#   'No focus track / Customized focus track': 1,
#   'AI': 2,
#   'Data Analytics': 3,
#   'Financial Technology': 0,
#   'Security': 0,
#   'Others': 0,
#   'python': 3,
#   'pytorch': 4,
#   'recurrent': 1,
#   'neural': 2,
#   'network': 2,
#   'convolution': 1,
#   'initialisation': 1,
#   'dataloader': 1,
#   'data': 1,
#   'visualisation': 1},
#  '50.040 Natural Language Processing': {'ESD': 2,
#   'ISTD': 1,
#   'Aviation': 0,
#   'Business Analytics and Operations Research': 0,
#   'Financial Services': 1,
#   'Supply Chain & Logistics': 0,
#   'Urban Infrastructure Systems': 0,
#   'No focus track / Customized focus track': 1,
#   'AI': 0,
#   'Data Analytics': 1,
#   'Financial Technology': 0,
#   'Security': 0,
#   'Others': 0,
#   'nlp': 2,
#   'cod': 1,
#   'python': 2,
#   'data': 1,
#   'management': 1,
#   'nltk': 1,
#   'pytorch': 1},
#  '50.041 Distributed Systems and Computing': {'ISTD': 2,
#   'Aviation': 0,
#   'Business Analytics and Operations Research': 0,
#   'Financial Services': 0,
#   'Supply Chain & Logistics': 0,
#   'Urban Infrastructure Systems': 0,
#   'No focus track / Customized focus track': 0,
#   'AI': 0,
#   'Data Analytics': 1,
#   'Financial Technology': 0,
#   'Security': 1,
#   'Others': 0,
#   'learnt': 1,
#   'pain': 1,
#   'ensure': 1,
#   'consistency': 1,
#   'fault': 1,
#   'tolerance': 1,
#   'java': 1,
#   'software': 1,
#   'development': 1,
#   'teamwork': 1},
#  '50.042 Foundations of Cybersecurity': {'ISTD': 1,
#   'Aviation': 0,
#   'Business Analytics and Operations Research': 0,
#   'Financial Services': 0,
#   'Supply Chain & Logistics': 0,
#   'Urban Infrastructure Systems': 0,
#   'No focus track / Customized focus track': 0,
#   'AI': 0,
#   'Data Analytics': 0,
#   'Financial Technology': 0,
#   'Security': 1,
#   'Others': 0,
#   'learn': 1,
#   'crypto': 1},
#  '50.043 Database Systems / Database and Big Data Systems (for class 2021)': {'ISTD': 8,
#   'Aviation': 0,
#   'Business Analytics and Operations Research': 0,
#   'Financial Services': 0,
#   'Supply Chain & Logistics': 0,
#   'Urban Infrastructure Systems': 0,
#   'No focus track / Customized focus track': 0,
#   'AI': 2,
#   'Data Analytics': 6,
#   'Financial Technology': 1,
#   'Security': 1,
#   'Others': 0,
#   'learn': 1,
#   'devops': 1,
#   'relational': 1,
#   'algebra': 1,
#   'mysql': 3,
#   'mongodb': 3,
#   'flask': 1,
#   'reactjs': 1,
#   'hadoop': 3,
#   'spark': 2,
#   'intro': 1,
#   'aws': 3,
#   'cloud': 1,
#   'service': 1,
#   'sql': 4,
#   'python': 2,
#   'mapreduce': 1,
#   'pyspark': 1,
#   'map': 1,
#   'reduce': 1,
#   'javascript': 2,
#   'nosql': 1,
#   'mongo': 1,
#   's': 1,
#   'ec': 1,
#   'react': 1,
#   'node': 1,
#   'automation': 1,
#   'script': 1,
#   'database': 1,
#   'web': 1,
#   'development': 1},
#  '50.044 System Security': {'ISTD': 1,
#   'Aviation': 0,
#   'Business Analytics and Operations Research': 0,
#   'Financial Services': 0,
#   'Supply Chain & Logistics': 0,
#   'Urban Infrastructure Systems': 0,
#   'No focus track / Customized focus track': 0,
#   'AI': 0,
#   'Data Analytics': 0,
#   'Financial Technology': 0,
#   'Security': 1,
#   'Others': 0,
#   'learn': 1,
#   'reverse': 1,
#   'engineering': 1,
#   'far': 1},
#  '50.045 Information Retrieval': {'ESD': 2,
#   'ISTD': 3,
#   'Aviation': 0,
#   'Business Analytics and Operations Research': 2,
#   'Financial Services': 0,
#   'Supply Chain & Logistics': 0,
#   'Urban Infrastructure Systems': 0,
#   'No focus track / Customized focus track': 0,
#   'AI': 2,
#   'Data Analytics': 3,
#   'Financial Technology': 0,
#   'Security': 0,
#   'Others': 0,
#   'implementation': 1,
#   'python': 3,
#   'pytorch': 1,
#   'sklearn': 1,
#   'document': 1,
#   'rank': 1,
#   'tfidf': 2,
#   'embed': 1,
#   'matrix': 1,
#   'index': 1},
#  '50.046 Cloud Computing and Internet of Things': {'ISTD': 1,
#   'Aviation': 0,
#   'Business Analytics and Operations Research': 0,
#   'Financial Services': 0,
#   'Supply Chain & Logistics': 0,
#   'Urban Infrastructure Systems': 0,
#   'No focus track / Customized focus track': 0,
#   'AI': 0,
#   'Data Analytics': 1,
#   'Financial Technology': 0,
#   'Security': 0,
#   'Others': 0,
#   'iot': 1,
#   'electronics': 1,
#   'aws': 1,
#   'esp': 1,
#   'raspberry': 1,
#   'pi': 1}}

# %%
def formattingTable(_dict):
    import pandas as pd
    wordDf = pd.DataFrame()
    for k,v in _dict.items():
        for k2,v2 in v.items():
            wordDf.at[ k2 ,k ] = v2
    wordDf.fillna(0, inplace = True)

    return(wordDf)

# %%
formattingTableDf = formattingTable(formattingSurveyDataDict)
formattingTableDf
# Out:
#                                             40.240 Investment Science  \
# ESD                                                               4.0
# Aviation                                                          0.0
# Business Analytics and Operations Research                        3.0
# Financial Services                                                3.0
# Supply Chain & Logistics                                          0.0
# ...                                                               ...
# index                                                             0.0
# iot                                                               0.0
# esp                                                               0.0
# raspberry                                                         0.0
# pi                                                                0.0
#
#                                             40.242 Derivative Pricing and Risk Management  \
# ESD                                                                                   3.0
# Aviation                                                                              0.0
# Business Analytics and Operations Research                                            2.0
# Financial Services                                                                    3.0
# Supply Chain & Logistics                                                              0.0
# ...                                                                                   ...
# index                                                                                 0.0
# iot                                                                                   0.0
# esp                                                                                   0.0
# raspberry                                                                             0.0
# pi                                                                                    0.0
#
#                                             40.260 Supply Chain Management  \
# ESD                                                                    2.0
# Aviation                                                               0.0
# Business Analytics and Operations Research                             1.0
# Financial Services                                                     0.0
# Supply Chain & Logistics                                               0.0
# ...                                                                    ...
# index                                                                  0.0
# iot                                                                    0.0
# esp                                                                    0.0
# raspberry                                                              0.0
# pi                                                                     0.0
#
#                                             40.302 Advanced Optim/ 40.305 Advanced Stochastic  \
# ESD                                                                                       1.0
# Aviation                                                                                  0.0
# Business Analytics and Operations Research                                                1.0
# Financial Services                                                                        0.0
# Supply Chain & Logistics                                                                  0.0
# ...                                                                                       ...
# index                                                                                     0.0
# iot                                                                                       0.0
# esp                                                                                       0.0
# raspberry                                                                                 0.0
# pi                                                                                        0.0
#
#                                             40.316 Game Theory  \
# ESD                                                       10.0
# Aviation                                                   0.0
# Business Analytics and Operations Research                10.0
# Financial Services                                         2.0
# Supply Chain & Logistics                                   0.0
# ...                                                        ...
# index                                                      0.0
# iot                                                        0.0
# esp                                                        0.0
# raspberry                                                  0.0
# pi                                                         0.0
#
#                                             40.317 Financial Systems Design  \
# ESD                                                                     2.0
# Aviation                                                                0.0
# Business Analytics and Operations Research                              2.0
# Financial Services                                                      2.0
# Supply Chain & Logistics                                                0.0
# ...                                                                     ...
# index                                                                   0.0
# iot                                                                     0.0
# esp                                                                     0.0
# raspberry                                                               0.0
# pi                                                                      0.0
#
#                                             40.318 Supply Chain Digitalisation and Design  \
# ESD                                                                                   0.0
# Aviation                                                                              0.0
# Business Analytics and Operations Research                                            0.0
# Financial Services                                                                    0.0
# Supply Chain & Logistics                                                              0.0
# ...                                                                                   ...
# index                                                                                 0.0
# iot                                                                                   0.0
# esp                                                                                   0.0
# raspberry                                                                             0.0
# pi                                                                                    0.0
#
#                                             40.319 Statistical and Machine Learning  \
# ESD                                                                            12.0
# Aviation                                                                        0.0
# Business Analytics and Operations Research                                     10.0
# Financial Services                                                              3.0
# Supply Chain & Logistics                                                        0.0
# ...                                                                             ...
# index                                                                           0.0
# iot                                                                             0.0
# esp                                                                             0.0
# raspberry                                                                       0.0
# pi                                                                              0.0
#
#                                             40.320 Airport Systems Planning and Design  \
# ESD                                                                                0.0
# Aviation                                                                           0.0
# Business Analytics and Operations Research                                         0.0
# Financial Services                                                                 0.0
# Supply Chain & Logistics                                                           0.0
# ...                                                                                ...
# index                                                                              0.0
# iot                                                                                0.0
# esp                                                                                0.0
# raspberry                                                                          0.0
# pi                                                                                 0.0
#
#                                             40.321 Airport Systems Modelling and Simulation  \
# ESD                                                                                     0.0
# Aviation                                                                                0.0
# Business Analytics and Operations Research                                              0.0
# Financial Services                                                                      0.0
# Supply Chain & Logistics                                                                0.0
# ...                                                                                     ...
# index                                                                                   0.0
# iot                                                                                     0.0
# esp                                                                                     0.0
# raspberry                                                                               0.0
# pi                                                                                      0.0
#
#                                             ...  50.037 Blockchain Technology  \
# ESD                                         ...                           0.0
# Aviation                                    ...                           0.0
# Business Analytics and Operations Research  ...                           0.0
# Financial Services                          ...                           0.0
# Supply Chain & Logistics                    ...                           0.0
# ...                                         ...                           ...
# index                                       ...                           0.0
# iot                                         ...                           0.0
# esp                                         ...                           0.0
# raspberry                                   ...                           0.0
# pi                                          ...                           0.0
#
#                                             50.038 Computational Data Science  \
# ESD                                                                       0.0
# Aviation                                                                  0.0
# Business Analytics and Operations Research                                0.0
# Financial Services                                                        0.0
# Supply Chain & Logistics                                                  0.0
# ...                                                                       ...
# index                                                                     0.0
# iot                                                                       0.0
# esp                                                                       0.0
# raspberry                                                                 0.0
# pi                                                                        0.0
#
#                                             50.039 Theory and Practice of Deep Learning  \
# ESD                                                                                 1.0
# Aviation                                                                            0.0
# Business Analytics and Operations Research                                          0.0
# Financial Services                                                                  0.0
# Supply Chain & Logistics                                                            0.0
# ...                                                                                 ...
# index                                                                               0.0
# iot                                                                                 0.0
# esp                                                                                 0.0
# raspberry                                                                           0.0
# pi                                                                                  0.0
#
#                                             50.040 Natural Language Processing  \
# ESD                                                                        2.0
# Aviation                                                                   0.0
# Business Analytics and Operations Research                                 0.0
# Financial Services                                                         1.0
# Supply Chain & Logistics                                                   0.0
# ...                                                                        ...
# index                                                                      0.0
# iot                                                                        0.0
# esp                                                                        0.0
# raspberry                                                                  0.0
# pi                                                                         0.0
#
#                                             50.041 Distributed Systems and Computing  \
# ESD                                                                              0.0
# Aviation                                                                         0.0
# Business Analytics and Operations Research                                       0.0
# Financial Services                                                               0.0
# Supply Chain & Logistics                                                         0.0
# ...                                                                              ...
# index                                                                            0.0
# iot                                                                              0.0
# esp                                                                              0.0
# raspberry                                                                        0.0
# pi                                                                               0.0
#
#                                             50.042 Foundations of Cybersecurity  \
# ESD                                                                         0.0
# Aviation                                                                    0.0
# Business Analytics and Operations Research                                  0.0
# Financial Services                                                          0.0
# Supply Chain & Logistics                                                    0.0
# ...                                                                         ...
# index                                                                       0.0
# iot                                                                         0.0
# esp                                                                         0.0
# raspberry                                                                   0.0
# pi                                                                          0.0
#
#                                             50.043 Database Systems / Database and Big Data Systems (for class 2021)  \
# ESD                                                                                       0.0
# Aviation                                                                                  0.0
# Business Analytics and Operations Research                                                0.0
# Financial Services                                                                        0.0
# Supply Chain & Logistics                                                                  0.0
# ...                                                                                       ...
# index                                                                                     0.0
# iot                                                                                       0.0
# esp                                                                                       0.0
# raspberry                                                                                 0.0
# pi                                                                                        0.0
#
#                                             50.044 System Security  \
# ESD                                                            0.0
# Aviation                                                       0.0
# Business Analytics and Operations Research                     0.0
# Financial Services                                             0.0
# Supply Chain & Logistics                                       0.0
# ...                                                            ...
# index                                                          0.0
# iot                                                            0.0
# esp                                                            0.0
# raspberry                                                      0.0
# pi                                                             0.0
#
#                                             50.045 Information Retrieval  \
# ESD                                                                  2.0
# Aviation                                                             0.0
# Business Analytics and Operations Research                           2.0
# Financial Services                                                   0.0
# Supply Chain & Logistics                                             0.0
# ...                                                                  ...
# index                                                                1.0
# iot                                                                  0.0
# esp                                                                  0.0
# raspberry                                                            0.0
# pi                                                                   0.0
#
#                                             50.046 Cloud Computing and Internet of Things
# ESD                                                                                   0.0
# Aviation                                                                              0.0
# Business Analytics and Operations Research                                            0.0
# Financial Services                                                                    0.0
# Supply Chain & Logistics                                                              0.0
# ...                                                                                   ...
# index                                                                                 0.0
# iot                                                                                   1.0
# esp                                                                                   1.0
# raspberry                                                                             1.0
# pi                                                                                    1.0
#
# [277 rows x 29 columns]

# %%
formattingTableDf.to_csv('pre_corpus/surveyToBeTokenized.csv')

# %%
# displaying dataframe as an heatmap 
# with diverging colourmap as virdis
formattingTableDf.head().style.background_gradient(cmap ='coolwarm').set_properties(**{'font-size': '10px'})

# %%
# generating pairwise correlation
corr = formattingTableDf.corr()
# Displaying dataframe as an heatmap 
# with diverging colourmap as coolwarm
corr.style.background_gradient(cmap ='coolwarm')
# Out:
# C:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\formats\style.py:1126: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(s.to_numpy()) if vmin is None else vmin
# C:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\formats\style.py:1127: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(s.to_numpy()) if vmax is None else vmax
# <style  type="text/css" >
# #T_e04024cf_dfd2_11eb_9121_c858c02ac276row0_col0,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row1_col1,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row2_col2,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row3_col3,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row4_col4,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row5_col5,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row7_col7,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row10_col10,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row11_col11,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row12_col12,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row13_col13,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row14_col14,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row15_col15,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row16_col16,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row17_col17,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row18_col18,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row19_col19,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row20_col20,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row21_col21,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row22_col22,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row23_col23,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row24_col24,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row25_col25,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row26_col26,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row27_col27,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row28_col28{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_e04024cf_dfd2_11eb_9121_c858c02ac276row0_col1,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row13_col19{
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }#T_e04024cf_dfd2_11eb_9121_c858c02ac276row0_col2,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row10_col7,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row16_col0{
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }#T_e04024cf_dfd2_11eb_9121_c858c02ac276row0_col3,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row4_col5,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row5_col16,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row17_col12{
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }#T_e04024cf_dfd2_11eb_9121_c858c02ac276row0_col4,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row3_col16,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row5_col4,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row7_col1,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row17_col13{
#             background-color:  #dcdddd;
#             color:  #000000;
#         }#T_e04024cf_dfd2_11eb_9121_c858c02ac276row0_col5,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row17_col19,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row22_col18{
#             background-color:  #b7cff9;
#             color:  #000000;
#         }#T_e04024cf_dfd2_11eb_9121_c858c02ac276row0_col6,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row0_col8,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row0_col9,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row1_col6,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row1_col8,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row1_col9,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row2_col6,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row2_col8,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row2_col9,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row3_col6,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row3_col8,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row3_col9,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row4_col6,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row4_col8,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row4_col9,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row5_col6,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row5_col8,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row5_col9,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row6_col0,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row6_col1,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row6_col2,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row6_col3,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row6_col4,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row6_col5,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row6_col6,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row6_col7,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row6_col8,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row6_col9,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row6_col10,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row6_col11,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row6_col12,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row6_col13,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row6_col14,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row6_col15,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row6_col16,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row6_col17,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row6_col18,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row6_col19,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row6_col20,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row6_col21,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row6_col22,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row6_col23,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row6_col24,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row6_col25,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row6_col26,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row6_col27,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row6_col28,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row7_col6,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row7_col8,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row7_col9,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row8_col0,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row8_col1,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row8_col2,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row8_col3,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row8_col4,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row8_col5,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row8_col6,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row8_col7,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row8_col8,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row8_col9,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row8_col10,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row8_col11,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row8_col12,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row8_col13,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row8_col14,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row8_col15,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row8_col16,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row8_col17,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row8_col18,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row8_col19,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row8_col20,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row8_col21,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row8_col22,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row8_col23,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row8_col24,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row8_col25,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row8_col26,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row8_col27,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row8_col28,#T_e04024cf_dfd2_11eb_9121_c858c02ac276row9_col0,#T_e04024cf_dfd2_11eb_9121_c858c0 ...

# %% [markdown]
# # Cleaning the the index words
# <br> don't use the function below, there are some faults with the code

# %%
def cleaningIndexedWord(_formattingTableDf):
    print('Starting to CleanIndexWords in to a single word for each row')
    print('There are currently: {}\n'.format(len(_formattingTableDf)))
    import pandas as pd
    newDf = pd.DataFrame(columns=_formattingTableDf.columns)
    ## counter to track which row it is at
    counter = 0

    for index, singleWordMertics in _formattingTableDf.iterrows():
        # print(index.lower())
        # print(singleWordMertics)
        cleanedDoc = textCleaning(index)
        for word in cleanedDoc:
            for elective, count in singleWordMertics.items():
                newDf.at[ word ,elective ] = count
    ## tracker
        counter += 1
        if counter % 10 == 0:
            print('Currently Done {}%'.format(round(counter*100/len(_formattingTableDf),2))) 
    return(newDf)

# %%
cleaningIndexedWordDf = cleaningIndexedWord(formattingTableDf)
# Out:
# Starting to CleanIndexWords in to a single word for each row
# There are currently: 277
#
# Currently Done 3.61%
# Currently Done 7.22%
# Currently Done 10.83%
# Currently Done 14.44%
# Currently Done 18.05%
# Currently Done 21.66%
# Currently Done 25.27%
# Currently Done 28.88%
# Currently Done 32.49%
# Currently Done 36.1%
# Currently Done 39.71%
# Currently Done 43.32%
# Currently Done 46.93%
# Currently Done 50.54%
# Currently Done 54.15%
# Currently Done 57.76%
# Currently Done 61.37%
# Currently Done 64.98%
# Currently Done 68.59%
# Currently Done 72.2%
# Currently Done 75.81%
# Currently Done 79.42%
# Currently Done 83.03%
# Currently Done 86.64%
# Currently Done 90.25%
# Currently Done 93.86%
# Currently Done 97.47%

# %%
cleaningIndexedWordDf
# Out:
#           40.240 Investment Science  \
# esd                               4
# aviation                          0
# business                          0
# analytics                         0
# operation                         3
# ...                             ...
# index                             0
# iot                               0
# esp                               0
# raspberry                         0
# pi                                0
#
#           40.242 Derivative Pricing and Risk Management  \
# esd                                                   3
# aviation                                              0
# business                                              0
# analytics                                             0
# operation                                             2
# ...                                                 ...
# index                                                 0
# iot                                                   0
# esp                                                   0
# raspberry                                             0
# pi                                                    0
#
#           40.260 Supply Chain Management  \
# esd                                    2
# aviation                               0
# business                               0
# analytics                              0
# operation                              1
# ...                                  ...
# index                                  0
# iot                                    0
# esp                                    0
# raspberry                              0
# pi                                     0
#
#           40.302 Advanced Optim/ 40.305 Advanced Stochastic  \
# esd                                                       1
# aviation                                                  0
# business                                                  0
# analytics                                                 0
# operation                                                 1
# ...                                                     ...
# index                                                     0
# iot                                                       0
# esp                                                       0
# raspberry                                                 0
# pi                                                        0
#
#           40.316 Game Theory 40.317 Financial Systems Design  \
# esd                       10                               2
# aviation                   0                               0
# business                   1                               0
# analytics                  1                               0
# operation                 10                               2
# ...                      ...                             ...
# index                      0                               0
# iot                        0                               0
# esp                        0                               0
# raspberry                  0                               0
# pi                         0                               0
#
#           40.318 Supply Chain Digitalisation and Design  \
# esd                                                   0
# aviation                                              0
# business                                              0
# analytics                                             0
# operation                                             0
# ...                                                 ...
# index                                                 0
# iot                                                   0
# esp                                                   0
# raspberry                                             0
# pi                                                    0
#
#           40.319 Statistical and Machine Learning  \
# esd                                            12
# aviation                                        0
# business                                        0
# analytics                                       1
# operation                                      10
# ...                                           ...
# index                                           0
# iot                                             0
# esp                                             0
# raspberry                                       0
# pi                                              0
#
#           40.320 Airport Systems Planning and Design  \
# esd                                                0
# aviation                                           0
# business                                           0
# analytics                                          0
# operation                                          0
# ...                                              ...
# index                                              0
# iot                                                0
# esp                                                0
# raspberry                                          0
# pi                                                 0
#
#           40.321 Airport Systems Modelling and Simulation  ...  \
# esd                                                     0  ...
# aviation                                                0  ...
# business                                                0  ...
# analytics                                               0  ...
# operation                                               0  ...
# ...                                                   ...  ...
# index                                                   0  ...
# iot                                                     0  ...
# esp                                                     0  ...
# raspberry                                               0  ...
# pi                                                      0  ...
#
#           50.037 Blockchain Technology 50.038 Computational Data Science  \
# esd                                  0                                 0
# aviation                             0                                 0
# business                             0                                 0
# analytics                            1                                 6
# operation                            0                                 0
# ...                                ...                               ...
# index                                0                                 0
# iot                                  0                                 0
# esp                                  0                                 0
# raspberry                            0                                 0
# pi                                   0                                 0
#
#           50.039 Theory and Practice of Deep Learning  \
# esd                                                 1
# aviation                                            0
# business                                            0
# analytics                                           3
# operation                                           0
# ...                                               ...
# index                                               0
# iot                                                 0
# esp                                                 0
# raspberry                                           0
# pi                                                  0
#
#           50.040 Natural Language Processing  \
# esd                                        2
# aviation                                   0
# business                                   0
# analytics                                  1
# operation                                  0
# ...                                      ...
# index                                      0
# iot                                        0
# esp                                        0
# raspberry                                  0
# pi                                         0
#
#           50.041 Distributed Systems and Computing  \
# esd                                              0
# aviation                                         0
# business                                         0
# analytics                                        1
# operation                                        0
# ...                                            ...
# index                                            0
# iot                                              0
# esp                                              0
# raspberry                                        0
# pi                                               0
#
#           50.042 Foundations of Cybersecurity  \
# esd                                         0
# aviation                                    0
# business                                    0
# analytics                                   0
# operation                                   0
# ...                                       ...
# index                                       0
# iot                                         0
# esp                                         0
# raspberry                                   0
# pi                                          0
#
#           50.043 Database Systems / Database and Big Data Systems (for class 2021)  \
# esd                                                        0
# aviation                                                   0
# business                                                   0
# analytics                                                  6
# operation                                                  0
# ...                                                      ...
# index                                                      0
# iot                                                        0
# esp                                                        0
# raspberry                                                  0
# pi                                                         0
#
#           50.044 System Security 50.045 Information Retrieval  \
# esd                            0                            2
# aviation                       0                            0
# business                       0                            0
# analytics                      0                            3
# operation                      0                            2
# ...                          ...                          ...
# index                          0                            1
# iot                            0                            0
# esp                            0                            0
# raspberry                      0                            0
# pi                             0                            0
#
#           50.046 Cloud Computing and Internet of Things
# esd                                                   0
# aviation                                              0
# business                                              0
# analytics                                             1
# operation                                             0
# ...                                                 ...
# index                                                 0
# iot                                                   1
# esp                                                   1
# raspberry                                             1
# pi                                                    1
#
# [275 rows x 29 columns]

# %%
# cleaningIndexedWordDf.to_csv('suveryToAddToTrainingSet/surveyTokenized.csv')
