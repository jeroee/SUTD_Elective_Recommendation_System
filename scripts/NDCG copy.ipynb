# %%
## from week 6 lab
def dcg_at_k(r, k, method=0):
    """Score is discounted cumulative gain (dcg)

    Relevance is positive real values.  Can use binary
    as the previous methods.

    Example from
    http://www.stanford.edu/class/cs276/handouts/EvaluationNew-handout-6-per.pdf
    >>> r = [3, 2, 3, 0, 0, 1, 2, 2, 3, 0]
    >>> dcg_at_k(r, 1)
    3.0
    >>> dcg_at_k(r, 1, method=1)
    3.0
    >>> dcg_at_k(r, 2)
    5.0
    >>> dcg_at_k(r, 2, method=1)
    4.2618595071429155
    >>> dcg_at_k(r, 10)
    9.6051177391888114
    >>> dcg_at_k(r, 11)
    9.6051177391888114

    Args:
        r: Relevance scores (list or numpy) in rank order
            (first element is the first item)
        k: Number of results to consider
        method: If 0 then weights are [1.0, 1.0, 0.6309, 0.5, 0.4307, ...]

    Returns:
        Discounted cumulative gain
    """
    import numpy as np
    r = np.asfarray(r)[:k]
    if r.size: ## why is this r.size? when will this be false?
        return r[0] + np.sum(r[1:] / np.log2(np.arange(2, r.size + 1)))
    return 0.

# %%
## from week 6 lab
def ndcg_at_k(r, k, method=0):
    """Score is normalized discounted cumulative gain (ndcg)

    Relevance is positive real values.  Can use binary
    as the previous methods.

    Example from
    http://www.stanford.edu/class/cs276/handouts/EvaluationNew-handout-6-per.pdf
    >>> r = [3, 2, 3, 0, 0, 1, 2, 2, 3, 0]
    >>> ndcg_at_k(r, 1)
    1.0
    >>> r = [2, 1, 2, 0]
    >>> ndcg_at_k(r, 4)
    0.9203032077642922
    >>> ndcg_at_k(r, 4, method=1)
    0.96519546960144276
    >>> ndcg_at_k([0], 1)
    0.0
    >>> ndcg_at_k([1], 2)
    1.0

    Args:
        r: Relevance scores (list or numpy) in rank order
            (first element is the first item)
        k: Number of results to consider
        method: If 0 then weights are [1.0, 1.0, 0.6309, 0.5, 0.4307, ...]
                If 1 then weights are [1.0, 0.6309, 0.5, 0.4307, ...]

    Returns:
        Normalized discounted cumulative gain
    """
    import numpy as np

    dcg_max = dcg_at_k(sorted(r, reverse=True), k, method)
    if not dcg_max:
        return 0.
    print('For k is {}, DCG scorce is {}'.format(k,dcg_at_k(r, k, method)))
    print('For k is {}, IDCG scorce is {}'.format(k,dcg_max))
    return dcg_at_k(r, k, method) / dcg_max

# %%
def assigningBM25ScoreToRelevantAndRetrieved(_bm25ScoreDf, relevantDocsList):
    """[summary]
    This function helps to assign zero values to those non-relevant and retrieved documents
    It retents the score of those relevant and retrieved

    Args:
        _bm25ScoreDf ([dataframe]): [a dataframe where rows are modules and columns is the bm25 scores]
        relevantAndRetrievedDocs ([list]): [list of modules based on the golden standard(idea outcome based on survey)]
    """
    df = _bm25ScoreDf.copy(deep = False)
    irrelevantAndRetrievedDocsList = list(set(df.index) - set(relevantDocsList))
    
    for relevantAndRetrievedDoc in irrelevantAndRetrievedDocsList:
        df.loc[relevantAndRetrievedDoc]['bm25Score'] = 0
    """[summary]
    output is a df with score that are retrieved and relevant(relevant depends on the gold standard)
    """
    return(df)

# %%
def NDCGWithVariousK(retrievedDocsDf,listOfRelevantDocs, exportResults = 0, queryNum = '', fileName = 'test'):
    """[summary]
    This function compute the NDGC at vaious K

    Args:
        retrievedDocsDf ([dataframe]): [dataframe of retrieved documents and it's bm25 score]
        listOfRelevantDocs ([list]): [list of relevant Documents based on gold standard]
        exportResults (int, optional): [to determine to export ndcg results]. Defaults to 0 and 1 to export ndgc score
        fileName (str, optional): [fileName to be exported ideally it should be the "ndcg_score_'model name']. Defaults to 'test'.
    """
    ## assign zero values to those non-relevant and retrieved documents, It retain the score of those relevant and retrieved
    BM25ScoreToRelevantAndRetrieved = assigningBM25ScoreToRelevantAndRetrieved(retrievedDocsDf,listOfRelevantDocs)
    ## obtain the score of the BM25 of the relevant and retrieved modules
    BM25ScoreToRelevantAndRetrievedScoreList = list(BM25ScoreToRelevantAndRetrieved.bm25Score)
    
    ## dict to save NDCGScore ie {k(ranking):NDCG Score}
    NDCGScoreDict = {}
    for i in range(1,len(BM25ScoreToRelevantAndRetrievedScoreList)):
        ndcg_at_kScore = ndcg_at_k(BM25ScoreToRelevantAndRetrievedScoreList,i)
        print('For k is {}, NDCG scorce is {}\n'.format(i,ndcg_at_kScore))
        NDCGScoreDict[i] = ndcg_at_kScore
    
    ## convert dict to df for easier sorting analysis of the scores and exporting it to csv
    import pandas as pd
    NDCGDf = pd.DataFrame.from_dict(NDCGScoreDict,orient='index',columns=['NDCGScore{}'.format(queryNum)])
    NDCGDf.reset_index(inplace = True)
    ## rename the column to k columns 
    NDCGDf.rename(columns={"index": "k"}, inplace = True)
    
    ## to export the ndcg scores to csv if exportResults == 1
    if exportResults == 1:
        fileName = 'ndcg_score_{}.csv'.format(fileName)
        NDCGDf.to_csv('../results/ndcg_score/{}'.format(fileName))
    return(NDCGDf)

# %% [markdown]
# # Toy Problem formulation

# %%
"Test Case : the retrievedDocScore"
## assume docs are not in bm25 scorce order
retrievedDocs = ['D','C', 'B','A'] 
retrievedDocsScore = [0.43, 0.26, 0.03, 0.37]
## I realised that the score should be in ascending order of bm25 score hence I made some changes to fit our use case
# retrievedDocsScore = [0.43,  0.37, 0.26, 0.03]

## creating a retrievedDocsDf for test cases
## this should be the same format of the bm25 output
retrievedDocsDict = {}
for index in range(len(retrievedDocs)):
    retrievedDocsDict[retrievedDocs[index]] = retrievedDocsScore[index]
import pandas as pd
retrievedDocsDf1 = pd.DataFrame.from_dict(retrievedDocsDict,orient='index',columns = ['bm25Score'])

print('BM25 output:')
retrievedDocsDf1
# Out:
# BM25 output:
#    bm25Score
# D       0.43
# C       0.26
# B       0.03
# A       0.37

# %%
"Test Case : the retrievedDocScore"
## assume docs are not in bm25 scorce order
retrievedDocs = ['C','D', 'B','A'] 
retrievedDocsScore = [0.5, 0.3, 0.2, 0.1]
## I realised that the score should be in ascending order of bm25 score hence I made some changes to fit our use case
# retrievedDocsScore = [0.43,  0.37, 0.26, 0.03]

## creating a retrievedDocsDf for test cases
## this should be the same format of the bm25 output
retrievedDocsDict = {}
for index in range(len(retrievedDocs)):
    retrievedDocsDict[retrievedDocs[index]] = retrievedDocsScore[index]
import pandas as pd
retrievedDocsDf2 = pd.DataFrame.from_dict(retrievedDocsDict,orient='index',columns = ['bm25Score'])

print('BM25 output:')
retrievedDocsDf2
# Out:
# BM25 output:
#    bm25Score
# C        0.5
# D        0.3
# B        0.2
# A        0.1

# %%
"Test Case : The Relevant Docs"
relevantDocs1 = ['B','D','E']
print('List of relevant Docs: {}'.format(relevantDocs1))
relevantDocs2 = ['A','C']
print('List of relevant Docs: {}'.format(relevantDocs2))
# Out:
# List of relevant Docs: ['B', 'D', 'E']
# List of relevant Docs: ['A', 'C']

# %%
retrievedlist = [retrievedDocsDf1,retrievedDocsDf2]
relevantlist =[relevantDocs1,relevantDocs2]

# %%
if __name__ == "__main__":
    ## test case
    import pandas as pd
    ## this index is meant to keep track of the NDCG score of each query
    queryIndex = 0
    for retrieved in retrievedlist:
    ## to compute the NDCG of a single query
        NDCGWithVariousKdf = NDCGWithVariousK(retrieved,relevantlist[queryIndex],0,queryIndex)
    ## if this is 1st NDCG score been compute, make it's df to NDCG df else merge with the current overall NDGC df
        if queryIndex == 0:
            NDCGDf = NDCGWithVariousKdf
        else:
            NDCGDf = pd.merge(NDCGDf, NDCGWithVariousKdf, on=["k"])
        queryIndex += 1
# Out:
# For k is 1, DCG scorce is 0.43
# For k is 1, IDCG scorce is 0.43
# For k is 1, NDCG scorce is 1.0
#
# For k is 2, DCG scorce is 0.43
# For k is 2, IDCG scorce is 0.45999999999999996
# For k is 2, NDCG scorce is 0.9347826086956522
#
# For k is 3, DCG scorce is 0.4489278926071437
# For k is 3, IDCG scorce is 0.45999999999999996
# For k is 3, NDCG scorce is 0.9759302013198777
#
# For k is 1, DCG scorce is 0.5
# For k is 1, IDCG scorce is 0.5
# For k is 1, NDCG scorce is 1.0
#
# For k is 2, DCG scorce is 0.5
# For k is 2, IDCG scorce is 0.6
# For k is 2, NDCG scorce is 0.8333333333333334
#
# For k is 3, DCG scorce is 0.5
# For k is 3, IDCG scorce is 0.6
# For k is 3, NDCG scorce is 0.8333333333333334

# %%
import pandas as pd 
import numpy as np
from gensim.models import KeyedVectors
from gensim.parsing.preprocessing import remove_stopwords
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
import operator
import time

# import logging
# logging.basicConfig(level=logging.INFO, format='%(message)s')
# logger = logging.getLogger()
# logger.addHandler(logging.FileHandler("logs/MAP.log", 'a'))
# print = logger.info


from utils.association_matrix import  get_top_k_associated_words, get_associated_words
from utils.query_processing import get_wordnet_pos, process_query, expand_query
from basic_bm25 import bm25_basic, get_result
from bm25_with_pseudo_relevance import bm25_pseudo_relevance_back
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
## function to compute the NDCG for cosine simliarities
def get_NDCG_cosine(query_val,tf):
    import CosineSimilarity
    ## compute Cosine simliarities score
    cosineSimDf = CosineSimilarity.rankedModuleOfCosineSim(query_val,tf)
    cosineSimDf = cosineSimDf.T
    return(cosineSimDf)

# %%
def clean_elective_names(relevant_results):
    # clean up the relevant course names 

    #https://stackoverflow.com/questions/2582138/finding-and-replacing-elements-in-a-list
    try:
        relevant_results = relevant_results.split(',')
        relevant_results = [x.replace("'",'') for x in relevant_results]
        relevant_results = [x.replace("[",'') for x in relevant_results]
        relevant_results = [x.replace("]",'') for x in relevant_results]
        relevant_results = [x.replace(" ",'',1) for x in relevant_results if x != relevant_results[0]]
    except:
        pass
    replacements = {
        ' 50.035 Computer Vision': '50.035 Computer Vision'
        ,'50.043 Database Systems / Database and Big Data Systems (for class 2021)': '50.043 Database Systems'
        }

    relevant_results = [replacements.get(x, x) for x in relevant_results]
    
    if '40.302 Advanced Optim/ 40.305 Advanced Stochastic' in relevant_results:
        relevant_results.remove('40.302 Advanced Optim/ 40.305 Advanced Stochastic')
        relevant_results.append('40.302 Advanced Topics in Optimisation#')
        relevant_results.append('40.305 Advanced Topics in Stochastic Modelling#')
    return relevant_results

# %%
## for Cosine Similarity (query expansion, course information)
import pandas as pd
tf = pd.read_csv('../data/course_info_scores/course_info_tf.csv', index_col = 0)
query_val= pd.read_csv('../data/survey/vaildation_sample_query.csv',index_col = 0)
pipeline2 = get_NDCG_cosine(query_val,tf)
# Out:
# Current computing Query: network, term, model, technology, probability
# Number of terms in corpus: 8
#
# Current computing Query: term, different, skill, mongodb, long
# C:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\spatial\distance.py:728: RuntimeWarning: invalid value encountered in double_scalars
#   dist = 1.0 - uv / np.sqrt(uu * vv)

# %%
import pandas as pd
queryCount = 0
NDCGDf = 0
for query,row in pipeline2.iterrows():
    ## create the df for retrieved docs and it's score
        retrievedDocsDict = {}
        cleanedElectives = clean_elective_names(row['topModules'])
        for index in range(len(row['topModules'])):
            retrievedDocsDict[cleanedElectives[index]] = row['topModulesScore'][index]
        import pandas as pd
        retrievedDocsDf = pd.DataFrame.from_dict(retrievedDocsDict,orient='index',columns = ['bm25Score'])
    
    ## cleaned golden/vaildation set modules
        print(retrievedDocsDf[list(retrievedDocsDf)[0]])
        print(validModules)
        validModules = clean_elective_names(query_val['expectedElectivesInOrder'][queryCount])
        print(validModules)
    ## to compute the NDCG of a single query
        NDCGWithVariousKdf = NDCGWithVariousK(retrievedDocsDf,validModules,0,queryCount)
    ## if this is 1st NDCG score been compute, make it's df to NDCG df else merge with the current overall NDGC df
        if queryCount == 0:
            NDCGDf = NDCGWithVariousKdf
        else:
            NDCGDf = pd.merge(NDCGDf, NDCGWithVariousKdf, on=["k"])
        queryCount += 1
# Out:
# 50.012 Networks                                                  0.33558
# 01.104 Networked Life                                            0.27537
# 40.319 Statistical and Machine Learning                          0.26261
# 01.117 Brain-Inspired Computing and its Applications (Term 8)    0.25574
# 40.305 Advanced Topics in Stochastic Modelling#                  0.25503
# 50.020 Network Security                                          0.22059
# 40.232 Water Resources Management                                0.21678
# 50.035 Computer Vision                                           0.20015
# 01.107 Urban Transportation                                      0.18570
# 50.039 Theory and Practice of Deep Learning                      0.17916
# Name: bm25Score, dtype: float64
# ['40.242 Derivative Pricing and Risk Management', '50.043 Database Systems', '50.038 Computational Data Science', '50.037 Blockchain Technology', '50.035 Computer Vision', '40.319 Statistical and Machine Learning', '40.324 Fundamentals of Investing', '40.260 Supply Chain Management', '40.302 Advanced Topics in Optimisation#', '40.305 Advanced Topics in Stochastic Modelling#']
# ['50.037 Blockchain Technology', '50.039 Theory and Practice of Deep Learning', '50.021 Artificial Intelligence', '50.035 Computer Vision', '40.324 Fundamentals of Investing', '40.316 Game Theory', '50.043 Database Systems', '40.317 Financial Systems Design', '40.302 Advanced Topics in Optimisation#', '40.305 Advanced Topics in Stochastic Modelling#']
# For k is 1, DCG scorce is 0.0
# For k is 1, IDCG scorce is 0.25503
# For k is 1, NDCG scorce is 0.0
#
# For k is 2, DCG scorce is 0.0
# For k is 2, IDCG scorce is 0.45518
# For k is 2, NDCG scorce is 0.0
#
# For k is 3, DCG scorce is 0.0
# For k is 3, IDCG scorce is 0.5682173746498623
# For k is 3, NDCG scorce is 0.0
#
# For k is 4, DCG scorce is 0.0
# For k is 4, IDCG scorce is 0.5682173746498623
# For k is 4, NDCG scorce is 0.0
#
# For k is 5, DCG scorce is 0.10983544260545743
# For k is 5, IDCG scorce is 0.5682173746498623
# For k is 5, NDCG scorce is 0.1932982824982049
#
# For k is 6, DCG scorce is 0.10983544260545743
# For k is 6, IDCG scorce is 0.5682173746498623
# For k is 6, NDCG scorce is 0.1932982824982049
#
# For k is 7, DCG scorce is 0.10983544260545743
# For k is 7, IDCG scorce is 0.5682173746498623
# For k is 7, NDCG scorce is 0.1932982824982049
#
# For k is 8, DCG scorce is 0.17655210927212409
# For k is 8, IDCG scorce is 0.5682173746498623
# For k is 8, NDCG scorce is 0.31071226813667246
#
# For k is 9, DCG scorce is 0.17655210927212409
# For k is 9, IDCG scorce is 0.5682173746498623
# For k is 9, NDCG scorce is 0.31071226813667246
#
# 40.240 Investment Science                            0.10359
# 40.232 Water Resources Management                    0.09270
# 50.033 Foundations of Game Design and Development    0.08893
# 50.035 Computer Vision                               0.08321
# 50.017 Graphics and Visualisation                    0.06656
# 40.320 Airport Systems Planning and Design           0.05533
# 01.104 Networked Life                                0.05520
# 50.021 Artificial Intelligence                       0.05506
# 40.242 Derivative Pricing and Risk Management        0.05281
# 01.107 Urban Transportation                          0.04963
# Name: bm25Score, dtype: float64
# ['50.037 Blockchain Technology', '50.039 Theory and Practice of Deep Learning', '50.021 Artificial Intelligence', '50.035 Computer Vision', '40.324 Fundamentals of Investing', '40.316 Game Theory', '50.043 Database Systems', '40.317 Financial Systems Design', '40.302 Advanced Topics in Optimisation#', '40.305 Advanced Topics in Stochastic Modelling#']
# ['50.043 Database Systems', '40.316 Game Theory', '50.046 Cloud Computing and Internet of Things', '50.007 Machine Learning', '40.242 Derivative Pricing and Risk Management', '40.260 Supply Chain Management', '40.317 Financial Systems Design', '40.318 Supply Chain Digitalisation and Design', '40.319 Statistical and Machine Learning']
# For k is 1, DCG scorce is 0.0
# For k is 1, IDCG scorce is 0.05281
# For k is 1, NDCG scorce is 0.0
#
# For k is 2, DCG scorce is 0.0
# For k is 2, IDCG scorce is 0.05281
# For k is 2, NDCG scorce is 0.0
#
# For k is 3, DCG scorce is 0.0
# For k is 3, IDCG scorce is 0.05281
# For k is 3, NDCG scorce is 0.0
#
# For k is 4, DCG scorce is 0.0
# For k is 4, IDCG scorce is 0.05281
# For k is 4, NDCG scorce is 0.0
#
# For k is 5, DCG scorce is 0.0
# For k is 5, IDCG scorce is 0.05281
# For k is 5, NDCG scorce is 0.0
#
# For k is 6, DCG scorce is 0.0
# For k is 6, IDCG scorce is 0.05281
# For k is 6, NDCG scorce is 0.0
#
# For k is 7, DCG scorce is 0.0
# For k is 7, IDCG scorce is 0.05281
# For k is 7, NDCG scorce is 0.0
#
# For k is 8, DCG scorce is 0.0
# For k is 8, IDCG scorce is 0.05281
# For k is 8, NDCG scorce is 0.0
#
# For k is 9, DCG scorce is 0.016659700143054335
# For k is 9, IDCG scorce is 0.05281
# For k is 9, NDCG scorce is 0.3154648767857287
#
# 50.038 Computational Data Science                                0.31274
# 50.043 Database Systems                                          0.18262
# 50.045 Information Retrieval                                     0.15149
# 40.320 Airport Systems Planning and Design                       0.14639
# 01.116 AI for Healthcare (Term 7)                                0.12689
# 01.117 Brain-Inspired Computing and its Applications (Term 8)    0.11128
# 50.039 Theory and Practice of Deep Learning                      0.11016
# 40.318 Supply Chain Digitalisation and Design                    0.10212
# 01.102 Energy Systems and Management                             0.09302
# 40.323 Equity Valuation                                          0.08607
# Name: bm25Score, dtype: float64
# ['50.043 Database Systems', '40.316 Game Theory', '50.046 Cloud Computing and Internet of Things', '50.007 Machine Learning', '40.242 Derivative Pricing and Risk Management', '40.260 Supply Chain Management', '40.317 Financial Systems Design', '40.318 Supply Chain Digitalisation and Design', '40.319 Statistical and Machine Learning']
# ['40.319 Statistical and Machine Learning', '50.021 Artificial Intelligence', '40.318 Supply Chain Digitalisation and Design', '40.260 Supply Chain Management', '50.007 Machine Learning', '50.038 Computational Data Science', '50.017 Graphics and Visualisation', '50.045 Information Retrieval', '40.302 Advanced Topics in Optimisation#', '40.305 Advanced Topics in Stochastic Modelling#']
# For k is 1, DCG scorce is 0.31274
# For k is 1, IDCG scorce is 0.31274
# For k is 1, NDCG scorce is 1.0
#
# For k is 2, DCG scorce is 0.31274
# For k is 2, IDCG scorce is 0.46423000000000003
# For k is 2, NDCG scorce is 0.6736746871163001
#
# For k is 3, DCG scorce is 0.4083195483685401
# For k is 3, IDCG scorce is 0.5286605464347173
# For k is 3, NDCG scorce is 0.7723662208618443
#
# For k is 4, DCG scorce is 0.4083195483685401
# For k is 4, IDCG scorce is 0.5286605464347173
# For k is 4, NDCG scorce is 0.7723662208618443
#
# For k is 5, DCG scorce is 0.4083195483685401
# For k is 5, IDCG scorce is 0.5286605464347173
# For k is 5, NDCG scorce is 0.7723662208618443
#
# For k is 6, DCG scorce is 0.4083195483685401
# For k is 6, IDCG scorce is 0.5286605464347173
# For k is 6, NDCG scorce is 0.7723662208618443
#
# For k is 7, DCG scorce is 0.4083195483685401
# For k is 7, IDCG scorce is 0.5286605464347173
# For k is 7, NDCG scorce is 0.7723662208618443
#
# For k is 8, DCG scorce is 0.44235954836854013
# For k is 8, IDCG scorce is 0.5286605464347173
# For k is 8, NDCG scorce is 0.8367553647644213
#
# For k is 9, DCG scorce is 0.44235954836854013
# For k is 9, IDCG scorce is 0.5286605464347173
# For k is 9, NDCG scorce is 0.8367553647644213
#
# 50.012 Networks                                                  0.32287
# 50.035 Computer Vision                                           0.19019
# 50.020 Network Security                                          0.18865
# 50.039 Theory and Practice of Deep Learning                      0.15822
# 50.021 Artificial Intelligence                                   0.12388
# 01.117 Brain-Inspired Computing and its Applications (Term 8)    0.10515
# 01.104 Networked Life                                            0.09200
# 40.302 Advanced Topics in Optimisation#                          0.08035
# 50.042 Foundations of Cybersecurity                              0.07597
# 50.045 Information Retrieval                                     0.07362
# Name: bm25Score, dtype: float64
# ['40.319 Statistical and Machine Learning', '50.021 Artificial Intelligence', '40.318 Supply Chain Digitalisation and Design', '40.260 Supply Chain Management', '50.007 Machine Learning', '50.038 Computational Data Science', '50.017 Graphics and Visualisation', '50.045 Information Retrieval', '40.302 Advanced Topics in Optimisation#', '40.305 Advanced Topics in Stochastic Modelling#']
# ['40.319 Statistical and Machine Learning', '50.021 Artificial Intelligence', '50.007 Machine Learning', '50.038 Computational Data Science', '50.037 Blockchain Technology', '40.323 Equity Valuation', '50.017 Graphics and Visualisation', '40.242 Derivative Pricing and Risk Management', '40.302 Advanced Topics in Optimisation#', '40.305 Advanced Topics in Stochastic Modelling#']
# For k is 1, DCG scorce is 0.0
# For k is 1, IDCG scorce is 0.12388
# For k is 1, NDCG scorce is 0.0
#
# For k is 2, DCG scorce is 0.0
# For k is 2, IDCG scorce is 0.20423000000000002
# For k is 2, NDCG scorce is 0.0
#
# For k is 3, DCG scorce is 0.0
# For k is 3, IDCG scorce is 0.20423000000000002
# For k is 3, NDCG scorce is 0.0
#
# For k is 4, DCG scorce is 0.0
# For k is 4, IDCG scorce is 0.20423000000000002
# For k is 4, NDCG scorce is 0.0
#
# For k is 5, DCG scorce is 0.053352212014131935
# For k is 5, IDCG scorce is 0.20423000000000002
# For k is 5, NDCG scorce is 0.26123592035514825
#
# For k is 6, DCG scorce is 0.053352212014131935
# For k is 6, IDCG scorce is 0.20423000000000002
# For k is 6, NDCG scorce is 0.26123592035514825
#
# For k is 7, DCG scorce is 0.053352212014131935
# For k is 7, IDCG scorce is 0.20423000000000002
# For k is 7, NDCG scorce is 0.26123592035514825
#
# For k is 8, DCG scorce is 0.08013554534746527
# For k is 8, IDCG scorce is 0.20423000000000002
# For k is 8, NDCG scorce is 0.39237891273302283
#
# For k is 9, DCG scorce is 0.08013554534746527
# For k is 9, IDCG scorce is 0.20423000000000002
# For k is 9, NDCG scorce is 0.39237891273302283
#
# 40.230 Sustainable Engineering                   0.15750
# 01.102 Energy Systems and Management             0.12970
# 50.045 Information Retrieval                     0.11734
# 50.042 Foundations of Cybersecurity              0.09082
# 40.320 Airport Systems Planning and Design       0.08819
# 40.242 Derivative Pricing and Risk Management    0.08418
# 40.324 Fundamentals of Investing                 0.08207
# 50.038 Computational Data Science                0.08075
# 50.040 Natural Language Processing               0.06841
# 50.039 Theory and Practice of Deep Learning      0.06827
# Name: bm25Score, dtype: float64
# ['40.319 Statistical and Machine Learning', '50.021 Artificial Intelligence', '50.007 Machine Learning', '50.038 Computational Data Science', '50.037 Blockchain Technology', '40.323 Equity Valuation', '50.017 Graphics and Visualisation', '40.242 Derivative Pricing and Risk Management', '40.302 Advanced Topics in Optimisation#', '40.305 Advanced Topics in Stochastic Modelling#']
# ['40.319 Statistical and Machine Learning', '50.021 Artificial Intelligence', '50.038 Computational Data Science', '50.007 Machine Learning', '50.017 Graphics and Visualisation', '40.242 Derivative Pricing and Risk Management', '40.260 Supply Chain Management', '40.318 Supply Chain Digitalisation and Design', '40.302 Advanced Topics in Optimisation#', '40.305 Advanced Topics in Stochastic Modelling#']
# For k is 1, DCG scorce is 0.0
# For k is 1, IDCG scorce is 0.08418
# For k is 1, NDCG scorce is 0.0
#
# For k is 2, DCG scorce is 0.0
# For k is 2, IDCG scorce is 0.16493000000000002
# For k is 2, NDCG scorce is 0.0
#
# For k is 3, DCG scorce is 0.0
# For k is 3, IDCG scorce is 0.16493000000000002
# For k is 3, NDCG scorce is 0.0
#
# For k is 4, DCG scorce is 0.0
# For k is 4, IDCG scorce is 0.16493000000000002
# For k is 4, NDCG scorce is 0.0
#
# For k is 5, DCG scorce is 0.0
# For k is 5, IDCG scorce is 0.16493000000000002
# For k is 5, NDCG scorce is 0.0
#
# For k is 6, DCG scorce is 0.032565269313003714
# For k is 6, IDCG scorce is 0.16493000000000002
# For k is 6, NDCG scorce is 0.19744903482085557
#
# For k is 7, DCG scorce is 0.032565269313003714
# For k is 7, IDCG scorce is 0.16493000000000002
# For k is 7, NDCG scorce is 0.19744903482085557
#
# For k is 8, DCG scorce is 0.059481935979670386
# For k is 8, IDCG scorce is 0.16493000000000002
# For k is 8, NDCG scorce is 0.3606495845490231
#
# For k is 9, DCG scorce is 0.059481935979670386
# For k is 9, IDCG scorce is 0.16493000000000002
# For k is 9, NDCG scorce is 0.3606495845490231
#
# 40.319 Statistical and Machine Learning                          0.22743
# 40.305 Advanced Topics in Stochastic Modelling#                  0.22086
# 40.232 Water Resources Management                                0.20025
# 50.048 Computational Fabrication                                 0.19181
# 50.042 Foundations of Cybersecurity                              0.18464
# 01.117 Brain-Inspired Computing and its Applications (Term 8)    0.18172
# 50.038 Computational Data Science                                0.16415
# 40.242 Derivative Pricing and Risk Management                    0.15211
# 40.323 Equity Valuation                                          0.14055
# 40.316 Game Theory                                               0.13656
# Name: bm25Score, dtype: float64
# ['40.319 Statistical and Machine Learning', '50.021 Artificial Intelligence', '50.038 Computational Data Science', '50.007 Machine Learning', '50.017 Graphics and Visualisation', '40.242 Derivative Pricing and Risk Management', '40.260 Supply Chain Management', '40.318 Supply Chain Digitalisation and Design', '40.302 Advanced Topics in Optimisation#', '40.305 Advanced Topics in Stochastic Modelling#']
# ['40.319 Statistical and Machine Learning', '40.324 Fundamentals of Investing', '40.316 Game Theory', '40.317 Financial Systems Design', '40.320 Airport Systems Planning and Design', '40.321 Airport Systems Modelling and Simulation', '50.021 Artificial Intelligence', '50.045 Information Retrieval', '50.007 Machine Learning']
# For k is 1, DCG scorce is 0.22743
# For k is 1, IDCG scorce is 0.22743
# For k is 1, NDCG scorce is 1.0
#
# For k is 2, DCG scorce is 0.22743
# For k is 2, IDCG scorce is 0.36399
# For k is 2, NDCG scorce is 0.6248248578257645
#
# For k is 3, DCG scorce is 0.22743
# For k is 3, IDCG scorce is 0.36399
# For k is 3, NDCG scorce is 0.6248248578257645
#
# For k is 4, DCG scorce is 0.22743
# For k is 4, IDCG scorce is 0.36399
# For k is 4, NDCG scorce is 0.6248248578257645
#
# For k is 5, DCG scorce is 0.22743
# For k is 5, IDCG scorce is 0.36399
# For k is 5, NDCG scorce is 0.6248248578257645
#
# For k is 6, DCG scorce is 0.22743
# For k is 6, IDCG scorce is 0.36399
# For k is 6, NDCG scorce is 0.6248248578257645
#
# For k is 7, DCG scorce is 0.22743
# For k is 7, IDCG scorce is 0.36399
# For k is 7, NDCG scorce is 0.6248248578257645
#
# For k is 8, DCG scorce is 0.22743
# For k is 8, IDCG scorce is 0.36399
# For k is 8, NDCG scorce is 0.6248248578257645
#
# For k is 9, DCG scorce is 0.22743
# For k is 9, IDCG scorce is 0.36399
# For k is 9, NDCG scorce is 0.6248248578257645
#
# 40.242 Derivative Pricing and Risk Management      0.15525
# 40.324 Fundamentals of Investing                   0.13622
# 40.318 Supply Chain Digitalisation and Design      0.12481
# 40.323 Equity Valuation                            0.08607
# 40.240 Investment Science                          0.04568
# 50.006 User Interface Design and Implementation    0.03551
# 50.017 Graphics and Visualisation                  0.02935
# 50.037 Blockchain Technology                       0.02311
# 50.039 Theory and Practice of Deep Learning        0.02203
# 01.107 Urban Transportation                        0.02188
# Name: bm25Score, dtype: float64
# ['40.319 Statistical and Machine Learning', '40.324 Fundamentals of Investing', '40.316 Game Theory', '40.317 Financial Systems Design', '40.320 Airport Systems Planning and Design', '40.321 Airport Systems Modelling and Simulation', '50.021 Artificial Intelligence', '50.045 Information Retrieval', '50.007 Machine Learning']
# ['40.323 Equity Valuation', '40.260 Supply Chain Management', '40.318 Supply Chain Digitalisation and Design', '40.319 Statistical and Machine Learning', '40.320 Airport Systems Planning and Design', '40.321 Airport Systems Modelling and Simulation', '50.046 Cloud Computing and Internet of Things', '50.007 Machine Learning', '40.242 Derivative Pricing and Risk Management']
# For k is 1, DCG scorce is 0.15525
# For k is 1, IDCG scorce is 0.15525
# For k is 1, NDCG scorce is 1.0
#
# For k is 2, DCG scorce is 0.15525
# For k is 2, IDCG scorce is 0.28006
# For k is 2, NDCG scorce is 0.5543454973934158
#
# For k is 3, DCG scorce is 0.2339963425432536
# For k is 3, IDCG scorce is 0.33436412388989534
# For k is 3, NDCG scorce is 0.699824908907714
#
# For k is 4, DCG scorce is 0.27703134254325357
# For k is 4, IDCG scorce is 0.33436412388989534
# For k is 4, NDCG scorce is 0.8285318990576835
#
# For k is 5, DCG scorce is 0.27703134254325357
# For k is 5, IDCG scorce is 0.33436412388989534
# For k is 5, NDCG scorce is 0.8285318990576835
#
# For k is 6, DCG scorce is 0.27703134254325357
# For k is 6, IDCG scorce is 0.33436412388989534
# For k is 6, NDCG scorce is 0.8285318990576835
#
# For k is 7, DCG scorce is 0.27703134254325357
# For k is 7, IDCG scorce is 0.33436412388989534
# For k is 7, NDCG scorce is 0.8285318990576835
#
# For k is 8, DCG scorce is 0.27703134254325357
# For k is 8, IDCG scorce is 0.33436412388989534
# For k is 8, NDCG scorce is 0.8285318990576835
#
# For k is 9, DCG scorce is 0.27703134254325357
# For k is 9, IDCG scorce is 0.33436412388989534
# For k is 9, NDCG scorce is 0.8285318990576835
#
# 50.038 Computational Data Science                                0.38720
# 50.043 Database Systems                                          0.37829
# 50.042 Foundations of Cybersecurity                              0.23451
# 40.319 Statistical and Machine Learning                          0.23212
# 01.117 Brain-Inspired Computing and its Applications (Term 8)    0.22257
# 50.045 Information Retrieval                                     0.21641
# 40.323 Equity Valuation                                          0.20082
# 40.232 Water Resources Management                                0.18394
# 40.305 Advanced Topics in Stochastic Modelling#                  0.18033
# 50.048 Computational Fabrication                                 0.17228
# Name: bm25Score, dtype: float64
# ['40.323 Equity Valuation', '40.260 Supply Chain Management', '40.318 Supply Chain Digitalisation and Design', '40.319 Statistical and Machine Learning', '40.320 Airport Systems Planning and Design', '40.321 Airport Systems Modelling and Simulation', '50.046 Cloud Computing and Internet of Things', '50.007 Machine Learning', '40.242 Derivative Pricing and Risk Management']
# ['50.043 Database Systems', '50.007 Machine Learning', '40.316 Game Theory', '50.038 Computational Data Science', '50.045 Information Retrieval', '50.039 Theory and Practice of Deep Learning', '40.319 Statistical and Machine Learning', '50.035 Computer Vision', '50.046 Cloud Computing and Internet of Things']
# For k is 1, DCG scorce is 0.3872
# For k is 1, IDCG scorce is 0.3872
# For k is 1, NDCG scorce is 1.0
#
# For k is 2, DCG scorce is 0.76549
# For k is 2, IDCG scorce is 0.76549
# For k is 2, NDCG scorce is 1.0
#
# For k is 3, DCG scorce is 0.76549
# For k is 3, IDCG scorce is 0.9119414143990068
# For k is 3, NDCG scorce is 0.8394069925034361
#
# For k is 4, DCG scorce is 0.8815500000000001
# For k is 4, IDCG scorce is 1.0201464143990067
# For k is 4, NDCG scorce is 0.8641406640823639
#
# For k is 5, DCG scorce is 0.8815500000000001
# For k is 5, IDCG scorce is 1.0201464143990067
# For k is 5, NDCG scorce is 0.8641406640823639
#
# For k is 6, DCG scorce is 0.9652688160136271
# For k is 6, IDCG scorce is 1.0201464143990067
# For k is 6, NDCG scorce is 0.9462061547138709
#
# For k is 7, DCG scorce is 0.9652688160136271
# For k is 7, IDCG scorce is 1.0201464143990067
# For k is 7, NDCG scorce is 0.9462061547138709
#
# For k is 8, DCG scorce is 0.9652688160136271
# For k is 8, IDCG scorce is 1.0201464143990067
# For k is 8, NDCG scorce is 0.9462061547138709
#
# For k is 9, DCG scorce is 0.9652688160136271
# For k is 9, IDCG scorce is 1.0201464143990067
# For k is 9, NDCG scorce is 0.9462061547138709
#
# 50.048 Computational Fabrication                                 0.18794
# 01.117 Brain-Inspired Computing and its Applications (Term 8)    0.11128
# Service Design Studio                                            0.10076
# 01.104 Networked Life                                            0.06491
# 40.232 Water Resources Management                                0.06131
# 40.319 Statistical and Machine Learning                          0.04642
# 50.038 Computational Data Science                                0.04468
# 50.036 Foundations of Distributed Autonomous Systems             0.04393
# 40.317 Financial Systems Design                                  0.03817
# 50.044 System Security                                           0.03733
# Name: bm25Score, dtype: float64
# ['50.043 Database Systems', '50.007 Machine Learning', '40.316 Game Theory', '50.038 Computational Data Science', '50.045 Information Retrieval', '50.039 Theory and Practice of Deep Learning', '40.319 Statistical and Machine Learning', '50.035 Computer Vision', '50.046 Cloud Computing and Internet of Things']
# ['50.043 Database Systems', '40.317 Financial Systems Design', '50.038 Computational Data Science', '50.046 Cloud Computing and Internet of Things', '50.006 User Interface Design and Implementation', '40.242 Derivative Pricing and Risk Management', '40.260 Supply Chain Management', '40.318 Supply Chain Digitalisation and Design', '40.302 Advanced Topics in Optimisation#', '40.305 Advanced Topics in Stochastic Modelling#']
# For k is 1, DCG scorce is 0.0
# For k is 1, IDCG scorce is 0.04468
# For k is 1, NDCG scorce is 0.0
#
# For k is 2, DCG scorce is 0.0
# For k is 2, IDCG scorce is 0.08285000000000001
# For k is 2, NDCG scorce is 0.0
#
# For k is 3, DCG scorce is 0.0
# For k is 3, IDCG scorce is 0.08285000000000001
# For k is 3, NDCG scorce is 0.0
#
# For k is 4, DCG scorce is 0.0
# For k is 4, IDCG scorce is 0.08285000000000001
# For k is 4, NDCG scorce is 0.0
#
# For k is 5, DCG scorce is 0.0
# For k is 5, IDCG scorce is 0.08285000000000001
# For k is 5, NDCG scorce is 0.0
#
# For k is 6, DCG scorce is 0.0
# For k is 6, IDCG scorce is 0.08285000000000001
# For k is 6, NDCG scorce is 0.0
#
# For k is 7, DCG scorce is 0.01591533711998643
# For k is 7, IDCG scorce is 0.08285000000000001
# For k is 7, NDCG scorce is 0.19209821508734373
#
# For k is 8, DCG scorce is 0.01591533711998643
# For k is 8, IDCG scorce is 0.08285000000000001
# For k is 8, NDCG scorce is 0.19209821508734373
#
# For k is 9, DCG scorce is 0.027956631466897697
# For k is 9, IDCG scorce is 0.08285000000000001
# For k is 9, NDCG scorce is 0.3374367105238104
#
# 40.320 Airport Systems Planning and Design                       0.18443
# 40.302 Advanced Topics in Optimisation#                          0.14062
# 40.242 Derivative Pricing and Risk Management                    0.08802
# 50.045 Information Retrieval                                     0.08588
# 50.040 Natural Language Processing                               0.08584
# 01.117 Brain-Inspired Computing and its Applications (Term 8)    0.08412
# 40.319 Statistical and Machine Learning                          0.07019
# 50.038 Computational Data Science                                0.06754
# 50.017 Graphics and Visualisation                                0.06656
# 40.318 Supply Chain Digitalisation and Design                    0.06433
# Name: bm25Score, dtype: float64
# ['50.043 Database Systems', '40.317 Financial Systems Design', '50.038 Computational Data Science', '50.046 Cloud Computing and Internet of Things', '50.006 User Interface Design and Implementation', '40.242 Derivative Pricing and Risk Management', '40.260 Supply Chain Management', '40.318 Supply Chain Digitalisation and Design', '40.302 Advanced Topics in Optimisation#', '40.305 Advanced Topics in Stochastic Modelling#']
# ['40.317 Financial Systems Design', '50.038 Computational Data Science', '40.324 Fundamentals of Investing', '50.046 Cloud Computing and Internet of Things', '50.007 Machine Learning', '40.242 Derivative Pricing and Risk Management', '40.316 Game Theory', '40.318 Supply Chain Digitalisation and Design', '40.302 Advanced Topics in Optimisation#', '40.305 Advanced Topics in Stochastic Modelling#']
# For k is 1, DCG scorce is 0.0
# For k is 1, IDCG scorce is 0.14062
# For k is 1, NDCG scorce is 0.0
#
# For k is 2, DCG scorce is 0.14062
# For k is 2, IDCG scorce is 0.22864
# For k is 2, NDCG scorce is 0.6150279916025192
#
# For k is 3, DCG scorce is 0.1961544369093597
# For k is 3, IDCG scorce is 0.27125299555621624
# For k is 3, NDCG scorce is 0.7231420117854785
#
# For k is 4, DCG scorce is 0.1961544369093597
# For k is 4, IDCG scorce is 0.30341799555621624
# For k is 4, NDCG scorce is 0.6464825415176038
#
# For k is 5, DCG scorce is 0.1961544369093597
# For k is 5, IDCG scorce is 0.30341799555621624
# For k is 5, NDCG scorce is 0.6464825415176038
#
# For k is 6, DCG scorce is 0.1961544369093597
# For k is 6, IDCG scorce is 0.30341799555621624
# For k is 6, NDCG scorce is 0.6464825415176038
#
# For k is 7, DCG scorce is 0.1961544369093597
# For k is 7, IDCG scorce is 0.30341799555621624
# For k is 7, NDCG scorce is 0.6464825415176038
#
# For k is 8, DCG scorce is 0.21866777024269302
# For k is 8, IDCG scorce is 0.30341799555621624
# For k is 8, NDCG scorce is 0.7206816123145174
#
# For k is 9, DCG scorce is 0.21866777024269302
# For k is 9, IDCG scorce is 0.30341799555621624
# For k is 9, NDCG scorce is 0.7206816123145174
#
# 50.046 Cloud Computing and Internet of Things        0.11078
# Service Design Studio                                0.08906
# 40.320 Airport Systems Planning and Design           0.08626
# 40.318 Supply Chain Digitalisation and Design        0.08425
# 01.107 Urban Transportation                          0.06964
# 01.104 Networked Life                                0.06884
# 50.035 Computer Vision                               0.05560
# 40.240 Investment Science                            0.04845
# 40.232 Water Resources Management                    0.04336
# 50.033 Foundations of Game Design and Development    0.04159
# Name: bm25Score, dtype: float64
# ['40.317 Financial Systems Design', '50.038 Computational Data Science', '40.324 Fundamentals of Investing', '50.046 Cloud Computing and Internet of Things', '50.007 Machine Learning', '40.242 Derivative Pricing and Risk Management', '40.316 Game Theory', '40.318 Supply Chain Digitalisation and Design', '40.302 Advanced Topics in Optimisation#', '40.305 Advanced Topics in Stochastic Modelling#']
# ['50.037 Blockchain Technology', '50.035 Computer Vision', '40.321 Airport Systems Modelling and Simulation', '50.007 Machine Learning', '40.320 Airport Systems Planning and Design', '50.021 Artificial Intelligence', '40.318 Supply Chain Digitalisation and Design', '40.324 Fundamentals of Investing', '50.039 Theory and Practice of Deep Learning']
# For k is 1, DCG scorce is 0.0
# For k is 1, IDCG scorce is 0.08626
# For k is 1, NDCG scorce is 0.0
#
# For k is 2, DCG scorce is 0.0
# For k is 2, IDCG scorce is 0.17051
# For k is 2, NDCG scorce is 0.0
#
# For k is 3, DCG scorce is 0.054424000543073926
# For k is 3, IDCG scorce is 0.20558969429857304
# For k is 3, NDCG scorce is 0.26472144301180406
#
# For k is 4, DCG scorce is 0.09654900054307393
# For k is 4, IDCG scorce is 0.20558969429857304
# For k is 4, NDCG scorce is 0.46961984584138783
#
# For k is 5, DCG scorce is 0.09654900054307393
# For k is 5, IDCG scorce is 0.20558969429857304
# For k is 5, NDCG scorce is 0.46961984584138783
#
# For k is 6, DCG scorce is 0.09654900054307393
# For k is 6, IDCG scorce is 0.20558969429857304
# For k is 6, NDCG scorce is 0.46961984584138783
#
# For k is 7, DCG scorce is 0.11635412014627997
# For k is 7, IDCG scorce is 0.20558969429857304
# For k is 7, NDCG scorce is 0.5659530772846115
#
# For k is 8, DCG scorce is 0.11635412014627997
# For k is 8, IDCG scorce is 0.20558969429857304
# For k is 8, NDCG scorce is 0.5659530772846115
#
# For k is 9, DCG scorce is 0.11635412014627997
# For k is 9, IDCG scorce is 0.20558969429857304
# For k is 9, NDCG scorce is 0.5659530772846115
#
# 40.302 Advanced Topics in Optimisation#                          0.14261
# 01.117 Brain-Inspired Computing and its Applications (Term 8)    0.04977
# 50.021 Artificial Intelligence                                   0.04886
# 50.007 Machine Learning                                          0.03357
# 40.260 Supply Chain Management                                   0.02429
# 50.038 Computational Data Science                                0.01998
# 01.116 AI for Healthcare (Term 7)                                0.01892
# 50.040 Natural Language Processing                               0.01693
# 50.036 Foundations of Distributed Autonomous Systems             0.00000
# 50.017 Graphics and Visualisation                                0.00000
# Name: bm25Score, dtype: float64
# ['50.037 Blockchain Technology', '50.035 Computer Vision', '40.321 Airport Systems Modelling and Simulation', '50.007 Machine Learning', '40.320 Airport Systems Planning and Design', '50.021 Artificial Intelligence', '40.318 Supply Chain Digitalisation and Design', '40.324 Fundamentals of Investing', '50.039 Theory and Practice of Deep Learning']
# ['50.007 Machine Learning', '50.021 Artificial Intelligence', '50.046 Cloud Computing and Internet of Things', '40.242 Derivative Pricing and Risk Management', '40.260 Supply Chain Management', '40.316 Game Theory', '40.317 Financial Systems Design', '40.318 Supply Chain Digitalisation and Design', '40.319 Statistical and Machine Learning']
# For k is 1, DCG scorce is 0.0
# For k is 1, IDCG scorce is 0.04886
# For k is 1, NDCG scorce is 0.0
#
# For k is 2, DCG scorce is 0.0
# For k is 2, IDCG scorce is 0.08243
# For k is 2, NDCG scorce is 0.0
#
# For k is 3, DCG scorce is 0.030827227759501412
# For k is 3, IDCG scorce is 0.09775528371425071
# For k is 3, NDCG scorce is 0.3153510131443405
#
# For k is 4, DCG scorce is 0.04761222775950141
# For k is 4, IDCG scorce is 0.09775528371425071
# For k is 4, NDCG scorce is 0.48705528694159506
#
# For k is 5, DCG scorce is 0.05807336135510413
# For k is 5, IDCG scorce is 0.09775528371425071
# For k is 5, NDCG scorce is 0.5940687720252428
#
# For k is 6, DCG scorce is 0.05807336135510413
# For k is 6, IDCG scorce is 0.09775528371425071
# For k is 6, NDCG scorce is 0.5940687720252428
#
# For k is 7, DCG scorce is 0.05807336135510413
# For k is 7, IDCG scorce is 0.09775528371425071
# For k is 7, NDCG scorce is 0.5940687720252428
#
# For k is 8, DCG scorce is 0.05807336135510413
# For k is 8, IDCG scorce is 0.09775528371425071
# For k is 8, NDCG scorce is 0.5940687720252428
#
# For k is 9, DCG scorce is 0.05807336135510413
# For k is 9, IDCG scorce is 0.09775528371425071
# For k is 9, NDCG scorce is 0.5940687720252428
#
# 40.302 Advanced Topics in Optimisation#                 0.28208
# 40.232 Water Resources Management                       0.10013
# 40.324 Fundamentals of Investing                        0.09269
# 40.242 Derivative Pricing and Risk Management           0.07606
# 40.321 Airport Systems Modelling and Simulation         0.06299
# 40.240 Investment Science                               0.05595
# 50.036 Foundations of Distributed Autonomous Systems    0.05381
# 50.021 Artificial Intelligence                          0.04460
# 01.104 Networked Life                                   0.03975
# 40.319 Statistical and Machine Learning                 0.03790
# Name: bm25Score, dtype: float64
# ['50.007 Machine Learning', '50.021 Artificial Intelligence', '50.046 Cloud Computing and Internet of Things', '40.242 Derivative Pricing and Risk Management', '40.260 Supply Chain Management', '40.316 Game Theory', '40.317 Financial Systems Design', '40.318 Supply Chain Digitalisation and Design', '40.319 Statistical and Machine Learning']
# ['40.260 Supply Chain Management', '50.039 Theory and Practice of Deep Learning', '40.323 Equity Valuation', '50.046 Cloud Computing and Internet of Things', '50.006 User Interface Design and Implementation', '40.242 Derivative Pricing and Risk Management', '40.316 Game Theory', '40.317 Financial Systems Design', '40.302 Advanced Topics in Optimisation#', '40.305 Advanced Topics in Stochastic Modelling#']
# For k is 1, DCG scorce is 0.28208
# For k is 1, IDCG scorce is 0.28208
# For k is 1, NDCG scorce is 1.0
#
# For k is 2, DCG scorce is 0.28208
# For k is 2, IDCG scorce is 0.35814
# For k is 2, NDCG scorce is 0.787624951136427
#
# For k is 3, DCG scorce is 0.28208
# For k is 3, IDCG scorce is 0.35814
# For k is 3, NDCG scorce is 0.787624951136427
#
# For k is 4, DCG scorce is 0.32011
# For k is 4, IDCG scorce is 0.35814
# For k is 4, NDCG scorce is 0.8938124755682135
#
# For k is 5, DCG scorce is 0.32011
# For k is 5, IDCG scorce is 0.35814
# For k is 5, NDCG scorce is 0.8938124755682135
#
# For k is 6, DCG scorce is 0.32011
# For k is 6, IDCG scorce is 0.35814
# For k is 6, NDCG scorce is 0.8938124755682135
#
# For k is 7, DCG scorce is 0.32011
# For k is 7, IDCG scorce is 0.35814
# For k is 7, NDCG scorce is 0.8938124755682135
#
# For k is 8, DCG scorce is 0.32011
# For k is 8, IDCG scorce is 0.35814
# For k is 8, NDCG scorce is 0.8938124755682135
#
# For k is 9, DCG scorce is 0.32011
# For k is 9, IDCG scorce is 0.35814
# For k is 9, NDCG scorce is 0.8938124755682135
#
# 40.324 Fundamentals of Investing                 0.12976
# 50.046 Cloud Computing and Internet of Things    0.11371
# 50.037 Blockchain Technology                     0.11323
# 40.323 Equity Valuation                          0.10541
# Service Design Studio                            0.10284
# 40.318 Supply Chain Digitalisation and Design    0.09728
# 01.107 Urban Transportation                      0.08041
# 01.104 Networked Life                            0.07949
# 40.240 Investment Science                        0.05595
# 40.320 Airport Systems Planning and Design       0.03984
# Name: bm25Score, dtype: float64
# ['40.260 Supply Chain Management', '50.039 Theory and Practice of Deep Learning', '40.323 Equity Valuation', '50.046 Cloud Computing and Internet of Things', '50.006 User Interface Design and Implementation', '40.242 Derivative Pricing and Risk Management', '40.316 Game Theory', '40.317 Financial Systems Design', '40.302 Advanced Topics in Optimisation#', '40.305 Advanced Topics in Stochastic Modelling#']
# ['40.323 Equity Valuation', '50.039 Theory and Practice of Deep Learning', '50.007 Machine Learning', '40.319 Statistical and Machine Learning', '50.021 Artificial Intelligence', '50.035 Computer Vision', '40.324 Fundamentals of Investing', '50.043 Database Systems', '40.317 Financial Systems Design']
# For k is 1, DCG scorce is 0.12976
# For k is 1, IDCG scorce is 0.12976
# For k is 1, NDCG scorce is 1.0
#
# For k is 2, DCG scorce is 0.12976
# For k is 2, IDCG scorce is 0.23517
# For k is 2, NDCG scorce is 0.5517710592337458
#
# For k is 3, DCG scorce is 0.12976
# For k is 3, IDCG scorce is 0.23517
# For k is 3, NDCG scorce is 0.5517710592337458
#
# For k is 4, DCG scorce is 0.182465
# For k is 4, IDCG scorce is 0.23517
# For k is 4, NDCG scorce is 0.7758855296168728
#
# For k is 5, DCG scorce is 0.182465
# For k is 5, IDCG scorce is 0.23517
# For k is 5, NDCG scorce is 0.7758855296168728
#
# For k is 6, DCG scorce is 0.182465
# For k is 6, IDCG scorce is 0.23517
# For k is 6, NDCG scorce is 0.7758855296168728
#
# For k is 7, DCG scorce is 0.182465
# For k is 7, IDCG scorce is 0.23517
# For k is 7, NDCG scorce is 0.7758855296168728
#
# For k is 8, DCG scorce is 0.182465
# For k is 8, IDCG scorce is 0.23517
# For k is 8, NDCG scorce is 0.7758855296168728
#
# For k is 9, DCG scorce is 0.182465
# For k is 9, IDCG scorce is 0.23517
# For k is 9, NDCG scorce is 0.7758855296168728
#
# 50.038 Computational Data Science                0.21192
# 40.323 Equity Valuation                          0.19052
# 40.317 Financial Systems Design                  0.16296
# 40.240 Investment Science                        0.15167
# 50.043 Database Systems                          0.14850
# 40.324 Fundamentals of Investing                 0.12923
# 40.318 Supply Chain Digitalisation and Design    0.11841
# 50.039 Theory and Practice of Deep Learning      0.10451
# 01.116 AI for Healthcare (Term 7)                0.09363
# 40.316 Game Theory                               0.07933
# Name: bm25Score, dtype: float64
# ['40.323 Equity Valuation', '50.039 Theory and Practice of Deep Learning', '50.007 Machine Learning', '40.319 Statistical and Machine Learning', '50.021 Artificial Intelligence', '50.035 Computer Vision', '40.324 Fundamentals of Investing', '50.043 Database Systems', '40.317 Financial Systems Design']
# ['40.316 Game Theory', '40.323 Equity Valuation', '50.007 Machine Learning', '50.021 Artificial Intelligence', '40.318 Supply Chain Digitalisation and Design', '50.035 Computer Vision', '50.037 Blockchain Technology', '50.039 Theory and Practice of Deep Learning', '50.043 Database Systems']
# For k is 1, DCG scorce is 0.0
# For k is 1, IDCG scorce is 0.19052
# For k is 1, NDCG scorce is 0.0
#
# For k is 2, DCG scorce is 0.19052
# For k is 2, IDCG scorce is 0.33902
# For k is 2, NDCG scorce is 0.5619727449707982
#
# For k is 3, DCG scorce is 0.19052
# For k is 3, IDCG scorce is 0.41372839212039625
# For k is 3, NDCG scorce is 0.4604953482248762
#
# For k is 4, DCG scorce is 0.19052
# For k is 4, IDCG scorce is 0.4659833921203963
# For k is 4, NDCG scorce is 0.4088557730202867
#
# For k is 5, DCG scorce is 0.2544754688738989
# For k is 5, IDCG scorce is 0.5001489634723586
# For k is 5, NDCG scorce is 0.5087993527111704
#
# For k is 6, DCG scorce is 0.2544754688738989
# For k is 6, IDCG scorce is 0.5001489634723586
# For k is 6, NDCG scorce is 0.5087993527111704
#
# For k is 7, DCG scorce is 0.2966539618993598
# For k is 7, IDCG scorce is 0.5001489634723586
# For k is 7, NDCG scorce is 0.5931312140283077
#
# For k is 8, DCG scorce is 0.33149062856602646
# For k is 8, IDCG scorce is 0.5001489634723586
# For k is 8, NDCG scorce is 0.6627837959807084
#
# For k is 9, DCG scorce is 0.33149062856602646
# For k is 9, IDCG scorce is 0.5001489634723586
# For k is 9, NDCG scorce is 0.6627837959807084
#
# 40.242 Derivative Pricing and Risk Management                    0.21735
# 50.048 Computational Fabrication                                 0.15661
# 40.324 Fundamentals of Investing                                 0.09082
# 40.318 Supply Chain Digitalisation and Design                    0.09077
# 40.232 Water Resources Management                                0.08175
# 01.104 Networked Life                                            0.08113
# 01.117 Brain-Inspired Computing and its Applications (Term 8)    0.05564
# 40.319 Statistical and Machine Learning                          0.04642
# 40.240 Investment Science                                        0.04568
# 50.035 Computer Vision                                           0.04193
# Name: bm25Score, dtype: float64
# ['40.316 Game Theory', '40.323 Equity Valuation', '50.007 Machine Learning', '50.021 Artificial Intelligence', '40.318 Supply Chain Digitalisation and Design', '50.035 Computer Vision', '50.037 Blockchain Technology', '50.039 Theory and Practice of Deep Learning', '50.043 Database Systems']
# ['50.017 Graphics and Visualisation', '50.038 Computational Data Science', '40.323 Equity Valuation', '50.007 Machine Learning', '40.242 Derivative Pricing and Risk Management', '40.260 Supply Chain Management', '40.317 Financial Systems Design', '40.318 Supply Chain Digitalisation and Design', '40.302 Advanced Topics in Optimisation#', '40.305 Advanced Topics in Stochastic Modelling#']
# For k is 1, DCG scorce is 0.21735
# For k is 1, IDCG scorce is 0.21735
# For k is 1, NDCG scorce is 1.0
#
# For k is 2, DCG scorce is 0.21735
# For k is 2, IDCG scorce is 0.30812
# For k is 2, NDCG scorce is 0.7054069842918343
#
# For k is 3, DCG scorce is 0.21735
# For k is 3, IDCG scorce is 0.30812
# For k is 3, NDCG scorce is 0.7054069842918343
#
# For k is 4, DCG scorce is 0.262735
# For k is 4, IDCG scorce is 0.30812
# For k is 4, NDCG scorce is 0.8527034921459171
#
# For k is 5, DCG scorce is 0.262735
# For k is 5, IDCG scorce is 0.30812
# For k is 5, NDCG scorce is 0.8527034921459171
#
# For k is 6, DCG scorce is 0.262735
# For k is 6, IDCG scorce is 0.30812
# For k is 6, NDCG scorce is 0.8527034921459171
#
# For k is 7, DCG scorce is 0.262735
# For k is 7, IDCG scorce is 0.30812
# For k is 7, NDCG scorce is 0.8527034921459171
#
# For k is 8, DCG scorce is 0.262735
# For k is 8, IDCG scorce is 0.30812
# For k is 8, NDCG scorce is 0.8527034921459171
#
# For k is 9, DCG scorce is 0.262735
# For k is 9, IDCG scorce is 0.30812
# For k is 9, NDCG scorce is 0.8527034921459171
#
# 40.260 Supply Chain Management                                   0.19202
# 50.048 Computational Fabrication                                 0.16611
# 40.318 Supply Chain Digitalisation and Design                    0.13239
# 40.305 Advanced Topics in Stochastic Modelling#                  0.12752
# 01.102 Energy Systems and Management                             0.05920
# 01.117 Brain-Inspired Computing and its Applications (Term 8)    0.05902
# 50.007 Machine Learning                                          0.05307
# 01.104 Networked Life                                            0.05163
# 50.038 Computational Data Science                                0.04739
# 40.232 Water Resources Management                                0.04336
# Name: bm25Score, dtype: float64
# ['50.017 Graphics and Visualisation', '50.038 Computational Data Science', '40.323 Equity Valuation', '50.007 Machine Learning', '40.242 Derivative Pricing and Risk Management', '40.260 Supply Chain Management', '40.317 Financial Systems Design', '40.318 Supply Chain Digitalisation and Design', '40.302 Advanced Topics in Optimisation#', '40.305 Advanced Topics in Stochastic Modelling#']
# ['40.260 Supply Chain Management', '40.316 Game Theory', '50.038 Computational Data Science', '50.046 Cloud Computing and Internet of Things', '40.242 Derivative Pricing and Risk Management', '40.317 Financial Systems Design', '40.318 Supply Chain Digitalisation and Design', '40.319 Statistical and Machine Learning', '40.302 Advanced Topics in Optimisation#', '40.305 Advanced Topics in Stochastic Modelling#']
# For k is 1, DCG scorce is 0.19202
# For k is 1, IDCG scorce is 0.19202
# For k is 1, NDCG scorce is 1.0
#
# For k is 2, DCG scorce is 0.19202
# For k is 2, IDCG scorce is 0.32441
# For k is 2, NDCG scorce is 0.5919053050152585
#
# For k is 3, DCG scorce is 0.2755487900753253
# For k is 3, IDCG scorce is 0.40486616217543225
# For k is 3, NDCG scorce is 0.6805922939935085
#
# For k is 4, DCG scorce is 0.3393087900753252
# For k is 4, IDCG scorce is 0.4285611621754323
# For k is 4, NDCG scorce is 0.791739476234733
#
# For k is 5, DCG scorce is 0.3393087900753252
# For k is 5, IDCG scorce is 0.4285611621754323
# For k is 5, NDCG scorce is 0.791739476234733
#
# For k is 6, DCG scorce is 0.3393087900753252
# For k is 6, IDCG scorce is 0.4285611621754323
# For k is 6, NDCG scorce is 0.791739476234733
#
# For k is 7, DCG scorce is 0.3393087900753252
# For k is 7, IDCG scorce is 0.4285611621754323
# For k is 7, NDCG scorce is 0.791739476234733
#
# For k is 8, DCG scorce is 0.3393087900753252
# For k is 8, IDCG scorce is 0.4285611621754323
# For k is 8, NDCG scorce is 0.791739476234733
#
# For k is 9, DCG scorce is 0.3542586705862009
# For k is 9, IDCG scorce is 0.4285611621754323
# For k is 9, NDCG scorce is 0.826623366401047
#
# 40.317 Financial Systems Design                    0.20244
# 40.240 Investment Science                          0.19380
# 40.318 Supply Chain Digitalisation and Design      0.18053
# 40.324 Fundamentals of Investing                   0.14449
# 40.323 Equity Valuation                            0.12172
# 40.305 Advanced Topics in Stochastic Modelling#    0.09564
# 40.316 Game Theory                                 0.05913
# Service Design Studio                              0.05344
# 01.104 Networked Life                              0.05163
# 40.242 Derivative Pricing and Risk Management      0.04940
# Name: bm25Score, dtype: float64
# ['40.260 Supply Chain Management', '40.316 Game Theory', '50.038 Computational Data Science', '50.046 Cloud Computing and Internet of Things', '40.242 Derivative Pricing and Risk Management', '40.317 Financial Systems Design', '40.318 Supply Chain Digitalisation and Design', '40.319 Statistical and Machine Learning', '40.302 Advanced Topics in Optimisation#', '40.305 Advanced Topics in Stochastic Modelling#']
# ['40.319 Statistical and Machine Learning', '50.021 Artificial Intelligence', '50.038 Computational Data Science', '50.007 Machine Learning', '50.017 Graphics and Visualisation', '40.260 Supply Chain Management', '40.318 Supply Chain Digitalisation and Design', '40.323 Equity Valuation', '40.302 Advanced Topics in Optimisation#', '40.305 Advanced Topics in Stochastic Modelling#']
# For k is 1, DCG scorce is 0.0
# For k is 1, IDCG scorce is 0.18053
# For k is 1, NDCG scorce is 0.0
#
# For k is 2, DCG scorce is 0.0
# For k is 2, IDCG scorce is 0.30225
# For k is 2, NDCG scorce is 0.0
#
# For k is 3, DCG scorce is 0.11390174841225521
# For k is 3, IDCG scorce is 0.36259212163157417
# For k is 3, NDCG scorce is 0.31413188984836665
#
# For k is 4, DCG scorce is 0.11390174841225521
# For k is 4, IDCG scorce is 0.36259212163157417
# For k is 4, NDCG scorce is 0.31413188984836665
#
# For k is 5, DCG scorce is 0.16632369906094863
# For k is 5, IDCG scorce is 0.36259212163157417
# For k is 5, NDCG scorce is 0.45870742671554315
#
# For k is 6, DCG scorce is 0.2033223015448602
# For k is 6, IDCG scorce is 0.36259212163157417
# For k is 6, NDCG scorce is 0.5607466059382662
#
# For k is 7, DCG scorce is 0.2033223015448602
# For k is 7, IDCG scorce is 0.36259212163157417
# For k is 7, NDCG scorce is 0.5607466059382662
#
# For k is 8, DCG scorce is 0.2033223015448602
# For k is 8, IDCG scorce is 0.36259212163157417
# For k is 8, NDCG scorce is 0.5607466059382662
#
# For k is 9, DCG scorce is 0.2033223015448602
# For k is 9, IDCG scorce is 0.36259212163157417
# For k is 9, NDCG scorce is 0.5607466059382662
#
# 40.317 Financial Systems Design                    0.12985
# 40.240 Investment Science                          0.12949
# 50.038 Computational Data Science                  0.10132
# 40.305 Advanced Topics in Stochastic Modelling#    0.06816
# 01.116 AI for Healthcare (Term 7)                  0.04796
# 40.232 Water Resources Management                  0.04635
# 50.021 Artificial Intelligence                     0.04129
# 40.324 Fundamentals of Investing                   0.03432
# 40.316 Game Theory                                 0.03161
# 40.230 Sustainable Engineering                     0.02882
# Name: bm25Score, dtype: float64
# ['40.319 Statistical and Machine Learning', '50.021 Artificial Intelligence', '50.038 Computational Data Science', '50.007 Machine Learning', '50.017 Graphics and Visualisation', '40.260 Supply Chain Management', '40.318 Supply Chain Digitalisation and Design', '40.323 Equity Valuation', '40.302 Advanced Topics in Optimisation#', '40.305 Advanced Topics in Stochastic Modelling#']
# ['50.021 Artificial Intelligence', '50.037 Blockchain Technology', '50.039 Theory and Practice of Deep Learning', '50.007 Machine Learning', '50.035 Computer Vision', '50.038 Computational Data Science', '40.324 Fundamentals of Investing', '40.316 Game Theory', '40.321 Airport Systems Modelling and Simulation']
# For k is 1, DCG scorce is 0.0
# For k is 1, IDCG scorce is 0.10132
# For k is 1, NDCG scorce is 0.0
#
# For k is 2, DCG scorce is 0.0
# For k is 2, IDCG scorce is 0.14261
# For k is 2, NDCG scorce is 0.0
#
# For k is 3, DCG scorce is 0.06392580263186007
# For k is 3, IDCG scorce is 0.16426350914257243
# For k is 3, NDCG scorce is 0.3891661816160015
#
# For k is 4, DCG scorce is 0.06392580263186007
# For k is 4, IDCG scorce is 0.1800685091425724
# For k is 4, NDCG scorce is 0.3550082295691452
#
# For k is 5, DCG scorce is 0.06392580263186007
# For k is 5, IDCG scorce is 0.1800685091425724
# For k is 5, NDCG scorce is 0.3550082295691452
#
# For k is 6, DCG scorce is 0.06392580263186007
# For k is 6, IDCG scorce is 0.1800685091425724
# For k is 6, NDCG scorce is 0.3550082295691452
#
# For k is 7, DCG scorce is 0.0786335973875503
# For k is 7, IDCG scorce is 0.1800685091425724
# ...
# For k is 7, IDCG scorce is 0.31712943460865356
# For k is 7, NDCG scorce is 0.9386894703792421
#
# For k is 8, DCG scorce is 0.3056093943477989
# For k is 8, IDCG scorce is 0.31712943460865356
# For k is 8, NDCG scorce is 0.9636740112910972
#
# For k is 9, DCG scorce is 0.3056093943477989
# For k is 9, IDCG scorce is 0.31712943460865356
# For k is 9, NDCG scorce is 0.9636740112910972
#
# 50.038 Computational Data Science                                0.33772
# 01.116 AI for Healthcare (Term 7)                                0.31972
# 50.043 Database Systems                                          0.17749
# 50.039 Theory and Practice of Deep Learning                      0.12491
# 01.117 Brain-Inspired Computing and its Applications (Term 8)    0.10515
# 40.323 Equity Valuation                                          0.09759
# 50.045 Information Retrieval                                     0.08588
# Service Design Studio                                            0.05712
# 40.318 Supply Chain Digitalisation and Design                    0.05146
# 50.021 Artificial Intelligence                                   0.04129
# Name: bm25Score, dtype: float64
# ['40.319 Statistical and Machine Learning', '50.007 Machine Learning', '50.021 Artificial Intelligence', '50.017 Graphics and Visualisation', '50.038 Computational Data Science', '40.318 Supply Chain Digitalisation and Design', '50.035 Computer Vision', '40.260 Supply Chain Management', '40.302 Advanced Topics in Optimisation#', '40.305 Advanced Topics in Stochastic Modelling#']
# ['50.035 Computer Vision', '50.007 Machine Learning', '50.039 Theory and Practice of Deep Learning', '50.038 Computational Data Science', '50.021 Artificial Intelligence', '50.037 Blockchain Technology', '40.324 Fundamentals of Investing', '50.045 Information Retrieval', '40.318 Supply Chain Digitalisation and Design']
# For k is 1, DCG scorce is 0.33772
# For k is 1, IDCG scorce is 0.33772
# For k is 1, NDCG scorce is 1.0
#
# For k is 2, DCG scorce is 0.33772
# For k is 2, IDCG scorce is 0.46263
# For k is 2, NDCG scorce is 0.7300002161554591
#
# For k is 3, DCG scorce is 0.33772
# For k is 3, IDCG scorce is 0.5168142472367168
# For k is 3, NDCG scorce is 0.653464957295022
#
# For k is 4, DCG scorce is 0.400175
# For k is 4, IDCG scorce is 0.5425442472367168
# For k is 4, NDCG scorce is 0.7375896105030493
#
# For k is 5, DCG scorce is 0.400175
# For k is 5, IDCG scorce is 0.5603268823195672
# For k is 5, NDCG scorce is 0.714181333480572
#
# For k is 6, DCG scorce is 0.400175
# For k is 6, IDCG scorce is 0.5603268823195672
# For k is 6, NDCG scorce is 0.714181333480572
#
# For k is 7, DCG scorce is 0.430766073228837
# For k is 7, IDCG scorce is 0.5603268823195672
# For k is 7, NDCG scorce is 0.7687763818248529
#
# For k is 8, DCG scorce is 0.430766073228837
# For k is 8, IDCG scorce is 0.5603268823195672
# For k is 8, NDCG scorce is 0.7687763818248529
#
# For k is 9, DCG scorce is 0.4469998957882306
# For k is 9, IDCG scorce is 0.5603268823195672
# For k is 9, NDCG scorce is 0.7977484391571568
#
# 40.302 Advanced Topics in Optimisation#                 0.22549
# 40.260 Supply Chain Management                          0.17282
# 40.318 Supply Chain Digitalisation and Design           0.15646
# 40.232 Water Resources Management                       0.13007
# 40.242 Derivative Pricing and Risk Management           0.06587
# 40.324 Fundamentals of Investing                        0.06422
# 40.240 Investment Science                               0.04845
# 40.321 Airport Systems Modelling and Simulation         0.04364
# 50.021 Artificial Intelligence                          0.03863
# 50.036 Foundations of Distributed Autonomous Systems    0.03495
# Name: bm25Score, dtype: float64
# ['50.035 Computer Vision', '50.007 Machine Learning', '50.039 Theory and Practice of Deep Learning', '50.038 Computational Data Science', '50.021 Artificial Intelligence', '50.037 Blockchain Technology', '40.324 Fundamentals of Investing', '50.045 Information Retrieval', '40.318 Supply Chain Digitalisation and Design']
# ['40.316 Game Theory', '40.320 Airport Systems Planning and Design', '50.035 Computer Vision', '40.321 Airport Systems Modelling and Simulation', '40.323 Equity Valuation', '50.046 Cloud Computing and Internet of Things', '50.007 Machine Learning', '40.242 Derivative Pricing and Risk Management', '40.302 Advanced Topics in Optimisation#', '40.305 Advanced Topics in Stochastic Modelling#']
# For k is 1, DCG scorce is 0.22549
# For k is 1, IDCG scorce is 0.22549
# For k is 1, NDCG scorce is 1.0
#
# For k is 2, DCG scorce is 0.22549
# For k is 2, IDCG scorce is 0.29136
# For k is 2, NDCG scorce is 0.7739222954420648
#
# For k is 3, DCG scorce is 0.22549
# For k is 3, IDCG scorce is 0.3188937744458584
# For k is 3, NDCG scorce is 0.7071006650783129
#
# For k is 4, DCG scorce is 0.22549
# For k is 4, IDCG scorce is 0.3188937744458584
# For k is 4, NDCG scorce is 0.7071006650783129
#
# For k is 5, DCG scorce is 0.2538586648802944
# For k is 5, IDCG scorce is 0.3188937744458584
# For k is 5, NDCG scorce is 0.7960602721750354
#
# For k is 6, DCG scorce is 0.2538586648802944
# For k is 6, IDCG scorce is 0.3188937744458584
# For k is 6, NDCG scorce is 0.7960602721750354
#
# For k is 7, DCG scorce is 0.2538586648802944
# For k is 7, IDCG scorce is 0.3188937744458584
# For k is 7, NDCG scorce is 0.7960602721750354
#
# For k is 8, DCG scorce is 0.26840533154696106
# For k is 8, IDCG scorce is 0.3188937744458584
# For k is 8, NDCG scorce is 0.8416762980505621
#
# For k is 9, DCG scorce is 0.26840533154696106
# For k is 9, IDCG scorce is 0.3188937744458584
# For k is 9, NDCG scorce is 0.8416762980505621
#
# 50.021 Artificial Intelligence                     0.12746
# 50.038 Computational Data Science                  0.08935
# 50.045 Information Retrieval                       0.08115
# 50.042 Foundations of Cybersecurity                0.07538
# 40.319 Statistical and Machine Learning            0.06964
# 40.318 Supply Chain Digitalisation and Design      0.05106
# 01.116 AI for Healthcare (Term 7)                  0.04230
# 50.037 Blockchain Technology                       0.03467
# 40.232 Water Resources Management                  0.03066
# 50.006 User Interface Design and Implementation    0.01776
# Name: bm25Score, dtype: float64
# ['40.316 Game Theory', '40.320 Airport Systems Planning and Design', '50.035 Computer Vision', '40.321 Airport Systems Modelling and Simulation', '40.323 Equity Valuation', '50.046 Cloud Computing and Internet of Things', '50.007 Machine Learning', '40.242 Derivative Pricing and Risk Management', '40.302 Advanced Topics in Optimisation#', '40.305 Advanced Topics in Stochastic Modelling#']
# ['40.260 Supply Chain Management', '50.038 Computational Data Science', '40.320 Airport Systems Planning and Design', '50.007 Machine Learning', '50.046 Cloud Computing and Internet of Things', '50.006 User Interface Design and Implementation', '40.242 Derivative Pricing and Risk Management', '40.316 Game Theory', '40.302 Advanced Topics in Optimisation#', '40.305 Advanced Topics in Stochastic Modelling#']
# For k is 1, DCG scorce is 0.0
# For k is 1, IDCG scorce is 0.08935
# For k is 1, NDCG scorce is 0.0
#
# For k is 2, DCG scorce is 0.08935
# For k is 2, IDCG scorce is 0.10711
# For k is 2, NDCG scorce is 0.8341891513397443
#
# For k is 3, DCG scorce is 0.08935
# For k is 3, IDCG scorce is 0.10711
# For k is 3, NDCG scorce is 0.8341891513397443
#
# For k is 4, DCG scorce is 0.08935
# For k is 4, IDCG scorce is 0.10711
# For k is 4, NDCG scorce is 0.8341891513397443
#
# For k is 5, DCG scorce is 0.08935
# For k is 5, IDCG scorce is 0.10711
# For k is 5, NDCG scorce is 0.8341891513397443
#
# For k is 6, DCG scorce is 0.08935
# For k is 6, IDCG scorce is 0.10711
# For k is 6, NDCG scorce is 0.8341891513397443
#
# For k is 7, DCG scorce is 0.08935
# For k is 7, IDCG scorce is 0.10711
# For k is 7, NDCG scorce is 0.8341891513397443
#
# For k is 8, DCG scorce is 0.08935
# For k is 8, IDCG scorce is 0.10711
# For k is 8, NDCG scorce is 0.8341891513397443
#
# For k is 9, DCG scorce is 0.08935
# For k is 9, IDCG scorce is 0.10711
# For k is 9, NDCG scorce is 0.8341891513397443
#
# 50.038 Computational Data Science                                0.25329
# 40.321 Airport Systems Modelling and Simulation                  0.23328
# 50.043 Database Systems                                          0.19228
# 40.320 Airport Systems Planning and Design                       0.16599
# 40.302 Advanced Topics in Optimisation#                          0.12053
# 50.039 Theory and Practice of Deep Learning                      0.11659
# 01.116 AI for Healthcare (Term 7)                                0.11190
# 40.323 Equity Valuation                                          0.09759
# 50.045 Information Retrieval                                     0.08588
# 01.117 Brain-Inspired Computing and its Applications (Term 8)    0.08412
# Name: bm25Score, dtype: float64
# ['40.260 Supply Chain Management', '50.038 Computational Data Science', '40.320 Airport Systems Planning and Design', '50.007 Machine Learning', '50.046 Cloud Computing and Internet of Things', '50.006 User Interface Design and Implementation', '40.242 Derivative Pricing and Risk Management', '40.316 Game Theory', '40.302 Advanced Topics in Optimisation#', '40.305 Advanced Topics in Stochastic Modelling#']
# ['40.320 Airport Systems Planning and Design', '50.007 Machine Learning', '40.318 Supply Chain Digitalisation and Design', '40.321 Airport Systems Modelling and Simulation', '50.046 Cloud Computing and Internet of Things', '40.242 Derivative Pricing and Risk Management', '40.260 Supply Chain Management', '40.317 Financial Systems Design', '40.302 Advanced Topics in Optimisation#', '40.305 Advanced Topics in Stochastic Modelling#']
# For k is 1, DCG scorce is 0.0
# For k is 1, IDCG scorce is 0.23328
# For k is 1, NDCG scorce is 0.0
#
# For k is 2, DCG scorce is 0.23328
# For k is 2, IDCG scorce is 0.39927
# For k is 2, NDCG scorce is 0.5842662859718987
#
# For k is 3, DCG scorce is 0.23328
# For k is 3, IDCG scorce is 0.47531596319796776
# For k is 3, NDCG scorce is 0.4907893234438657
#
# For k is 4, DCG scorce is 0.316275
# For k is 4, IDCG scorce is 0.47531596319796776
# For k is 4, NDCG scorce is 0.6653994910502771
#
# For k is 5, DCG scorce is 0.36818444554458607
# For k is 5, IDCG scorce is 0.47531596319796776
# For k is 5, NDCG scorce is 0.7746098891091489
#
# For k is 6, DCG scorce is 0.36818444554458607
# For k is 6, IDCG scorce is 0.47531596319796776
# For k is 6, NDCG scorce is 0.7746098891091489
#
# For k is 7, DCG scorce is 0.36818444554458607
# For k is 7, IDCG scorce is 0.47531596319796776
# For k is 7, NDCG scorce is 0.7746098891091489
#
# For k is 8, DCG scorce is 0.36818444554458607
# For k is 8, IDCG scorce is 0.47531596319796776
# For k is 8, NDCG scorce is 0.7746098891091489
#
# For k is 9, DCG scorce is 0.36818444554458607
# For k is 9, IDCG scorce is 0.47531596319796776
# For k is 9, NDCG scorce is 0.7746098891091489
#
# 40.318 Supply Chain Digitalisation and Design        0.19256
# 40.242 Derivative Pricing and Risk Management        0.14820
# 40.305 Advanced Topics in Stochastic Modelling#      0.06376
# Service Design Studio                                0.05344
# 40.324 Fundamentals of Investing                     0.03211
# 50.038 Computational Data Science                    0.03159
# 40.230 Sustainable Engineering                       0.02696
# 50.006 User Interface Design and Implementation      0.02511
# 01.107 Urban Transportation                          0.02321
# 50.033 Foundations of Game Design and Development    0.02080
# Name: bm25Score, dtype: float64
# ['40.320 Airport Systems Planning and Design', '50.007 Machine Learning', '40.318 Supply Chain Digitalisation and Design', '40.321 Airport Systems Modelling and Simulation', '50.046 Cloud Computing and Internet of Things', '40.242 Derivative Pricing and Risk Management', '40.260 Supply Chain Management', '40.317 Financial Systems Design', '40.302 Advanced Topics in Optimisation#', '40.305 Advanced Topics in Stochastic Modelling#']
# ['40.319 Statistical and Machine Learning', '50.021 Artificial Intelligence', '50.038 Computational Data Science', '50.007 Machine Learning', '50.045 Information Retrieval', '40.260 Supply Chain Management', '50.035 Computer Vision', '40.318 Supply Chain Digitalisation and Design', '40.302 Advanced Topics in Optimisation#', '40.305 Advanced Topics in Stochastic Modelling#']
# For k is 1, DCG scorce is 0.19256
# For k is 1, IDCG scorce is 0.19256
# For k is 1, NDCG scorce is 1.0
#
# For k is 2, DCG scorce is 0.19256
# For k is 2, IDCG scorce is 0.25632
# For k is 2, NDCG scorce is 0.7512484394506866
#
# For k is 3, DCG scorce is 0.23278808108771615
# For k is 3, IDCG scorce is 0.27625107091532236
# For k is 3, NDCG scorce is 0.8426685200401316
#
# For k is 4, DCG scorce is 0.23278808108771615
# For k is 4, IDCG scorce is 0.27625107091532236
# For k is 4, NDCG scorce is 0.8426685200401316
#
# For k is 5, DCG scorce is 0.23278808108771615
# For k is 5, IDCG scorce is 0.27625107091532236
# For k is 5, NDCG scorce is 0.8426685200401316
#
# For k is 6, DCG scorce is 0.2450087612682553
# For k is 6, IDCG scorce is 0.27625107091532236
# For k is 6, NDCG scorce is 0.8869061048576221
#
# For k is 7, DCG scorce is 0.2450087612682553
# For k is 7, IDCG scorce is 0.27625107091532236
# For k is 7, NDCG scorce is 0.8869061048576221
#
# For k is 8, DCG scorce is 0.2450087612682553
# For k is 8, IDCG scorce is 0.27625107091532236
# For k is 8, NDCG scorce is 0.8869061048576221
#
# For k is 9, DCG scorce is 0.2450087612682553
# For k is 9, IDCG scorce is 0.27625107091532236
# For k is 9, NDCG scorce is 0.8869061048576221
#
# 50.041 Distributed Systems and Computing                0.12372
# 40.305 Advanced Topics in Stochastic Modelling#         0.11043
# 40.316 Game Theory                                      0.10242
# 50.033 Foundations of Game Design and Development       0.07204
# 50.036 Foundations of Distributed Autonomous Systems    0.06726
# 40.302 Advanced Topics in Optimisation#                 0.06509
# 50.042 Foundations of Cybersecurity                     0.06155
# 50.012 Networks                                         0.05812
# 40.242 Derivative Pricing and Risk Management           0.05704
# 40.319 Statistical and Machine Learning                 0.05686
# Name: bm25Score, dtype: float64
# ['40.319 Statistical and Machine Learning', '50.021 Artificial Intelligence', '50.038 Computational Data Science', '50.007 Machine Learning', '50.045 Information Retrieval', '40.260 Supply Chain Management', '50.035 Computer Vision', '40.318 Supply Chain Digitalisation and Design', '40.302 Advanced Topics in Optimisation#', '40.305 Advanced Topics in Stochastic Modelling#']
# ['40.242 Derivative Pricing and Risk Management', '50.043 Database Systems', '50.038 Computational Data Science', '50.037 Blockchain Technology', '50.035 Computer Vision', '40.319 Statistical and Machine Learning', '40.324 Fundamentals of Investing', '40.260 Supply Chain Management', '40.302 Advanced Topics in Optimisation#', '40.305 Advanced Topics in Stochastic Modelling#']
# For k is 1, DCG scorce is 0.0
# For k is 1, IDCG scorce is 0.11043
# For k is 1, NDCG scorce is 0.0
#
# For k is 2, DCG scorce is 0.11043
# For k is 2, IDCG scorce is 0.17552
# For k is 2, NDCG scorce is 0.6291590701914311
#
# For k is 3, DCG scorce is 0.11043
# For k is 3, IDCG scorce is 0.21150823314371592
# For k is 3, NDCG scorce is 0.5221073352968008
#
# For k is 4, DCG scorce is 0.11043
# For k is 4, IDCG scorce is 0.23993823314371593
# For k is 4, NDCG scorce is 0.46024344912907517
#
# For k is 5, DCG scorce is 0.11043
# For k is 5, IDCG scorce is 0.23993823314371593
# For k is 5, NDCG scorce is 0.46024344912907517
#
# For k is 6, DCG scorce is 0.1356102492228963
# For k is 6, IDCG scorce is 0.23993823314371593
# For k is 6, NDCG scorce is 0.5651881629955563
#
# For k is 7, DCG scorce is 0.1356102492228963
# For k is 7, IDCG scorce is 0.23993823314371593
# For k is 7, NDCG scorce is 0.5651881629955563
#
# For k is 8, DCG scorce is 0.1356102492228963
# For k is 8, IDCG scorce is 0.23993823314371593
# For k is 8, NDCG scorce is 0.5651881629955563
#
# For k is 9, DCG scorce is 0.15360436579475428
# For k is 9, IDCG scorce is 0.23993823314371593
# For k is 9, NDCG scorce is 0.640182949512468

# %%
NDCGDf
# Out:
#    k  NDCGScore0  NDCGScore1  NDCGScore2  NDCGScore3  NDCGScore4  NDCGScore5  \
# 0  1    0.000000    0.000000    1.000000    0.000000    0.000000    1.000000
# 1  2    0.000000    0.000000    0.673675    0.000000    0.000000    0.624825
# 2  3    0.000000    0.000000    0.772366    0.000000    0.000000    0.624825
# 3  4    0.000000    0.000000    0.772366    0.000000    0.000000    0.624825
# 4  5    0.193298    0.000000    0.772366    0.261236    0.000000    0.624825
# 5  6    0.193298    0.000000    0.772366    0.261236    0.197449    0.624825
# 6  7    0.193298    0.000000    0.772366    0.261236    0.197449    0.624825
# 7  8    0.310712    0.000000    0.836755    0.392379    0.360650    0.624825
# 8  9    0.310712    0.315465    0.836755    0.392379    0.360650    0.624825
#
#    NDCGScore6  NDCGScore7  NDCGScore8  ...  NDCGScore20  NDCGScore21  \
# 0    1.000000    1.000000    0.000000  ...     1.000000     1.000000
# 1    0.554345    1.000000    0.000000  ...     0.626879     0.667943
# 2    0.699825    0.839407    0.000000  ...     0.707246     0.556132
# 3    0.828532    0.864141    0.000000  ...     0.849740     0.627582
# 4    0.828532    0.864141    0.000000  ...     0.849740     0.730857
# 5    0.828532    0.946206    0.000000  ...     0.849740     0.805274
# 6    0.828532    0.946206    0.192098  ...     0.849740     0.805274
# 7    0.828532    0.946206    0.192098  ...     0.849740     0.805274
# 8    0.828532    0.946206    0.337437  ...     0.849740     0.805274
#
#    NDCGScore22  NDCGScore23  NDCGScore24  NDCGScore25  NDCGScore26  \
# 0     1.000000     1.000000     1.000000     1.000000     0.000000
# 1     1.000000     1.000000     0.730000     0.773922     0.834189
# 2     0.823666     1.000000     0.653465     0.707101     0.834189
# 3     0.726308     0.961608     0.737590     0.707101     0.834189
# 4     0.663122     0.938689     0.714181     0.796060     0.834189
# 5     0.663122     0.938689     0.714181     0.796060     0.834189
# 6     0.743272     0.938689     0.768776     0.796060     0.834189
# 7     0.815217     0.963674     0.768776     0.841676     0.834189
# 8     0.815217     0.963674     0.797748     0.841676     0.834189
#
#    NDCGScore27  NDCGScore28  NDCGScore29
# 0     0.000000     1.000000     0.000000
# 1     0.584266     0.751248     0.629159
# 2     0.490789     0.842669     0.522107
# 3     0.665399     0.842669     0.460243
# 4     0.774610     0.842669     0.460243
# 5     0.774610     0.886906     0.565188
# 6     0.774610     0.886906     0.565188
# 7     0.774610     0.886906     0.565188
# 8     0.774610     0.886906     0.640183
#
# [9 rows x 31 columns]
